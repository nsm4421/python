# %%
import openpyxl 
import numpy as np
import urllib.request
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

# %% [markdown]
# Crawling

# %%
url = 'http://www.op.gg/champion/statistics'
html = urllib.request.urlopen(url).read()
soup = bs(html, 'html.parser')

champion_name = soup.select('div.champion-index-table__name')
champion_name = [name.string for name in champion_name]

infos = soup.select('td.champion-index-table__cell--value')
infos = [info.string for info in infos]
win_rate = infos[::3]
pick_rate = infos[1::3]

ranking = soup.select('td.champion-index-table__cell--rank')
ranking = [rank.string for rank in ranking] 

a = 1
b = 0 
position = []
for rank in ranking:
    if int(rank)<a:
        b+=1
    if b == 0:
        position.append('Top')
    elif b==1:
        position.append('Jugle')
    elif b==2:
        position.append('Mid')
    elif b==3:
        position.append('Ad')
    else:
        position.append('Support')
    a = int(rank)
    
win_rate = [float(rate.split('%')[0]) for rate in win_rate]
pick_rate = [float(rate.split('%')[0]) for rate in pick_rate]

data = pd.DataFrame({'ranking' : ranking, 
                       'name' : champion_name,
                       'win_rate' : win_rate,
                       'pick_rate' : pick_rate,
                       'position' : position})

data.head()
# Out:
#   ranking      name  win_rate  pick_rate position
# 0       1  Malphite     52.59      11.63      Top
# 1       2   Camille     51.14      14.70      Top
# 2       3  Pantheon     52.98       4.20      Top
# 3       4    Darius     51.99       6.02      Top
# 4       5    Aatrox     50.37      13.34      Top

# %% [markdown]
# Make Workbook

# %%
wb = openpyxl.Workbook()

# %% [markdown]
# Make Sheet

# %%
ws = wb.active

# %% [markdown]
# Change Sheet Name

# %%
ws.title = 'LoL Data From OP.GG'

# %% [markdown]
# Insert Values

# %%
# Way 1
ws['A1'] = 'LoL Data From OP.GG'
# Way 2
ws.append(list(data.columns))

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        # Way 3
        ws.cell(row = i+3, column = j+1).value = data.iloc[i, j]

# %% [markdown]
# Print Values

# %%
# Way 1
for row in ws.values:
    print('\n')
    for value in row:
        print(value, end = ' ')
# Out:
# LoL Data From OP.GG None None None None
#
# ranking name win_rate pick_rate position
#
# 1 Malphite 52.59 11.63 Top
#
# 2 Camille 51.14 14.7 Top
#
# 3 Pantheon 52.98 4.2 Top
#
# 4 Darius 51.99 6.02 Top
#
# 5 Aatrox 50.37 13.34 Top
#
# 6 Shen 50.96 7.91 Top
#
# 7 Maokai 52.12 3.57 Top
#
# 8 Ornn 50.48 10.03 Top
#
# 9 Akali 49.1 8.18 Top
#
# 10 Poppy 51.94 3.88 Top
#
# 11 Renekton 49.8 5.46 Top
#
# 12 Volibear 51.05 3.99 Top
#
# 13 Fiora 49.48 6.18 Top
#
# 14 Teemo 50.98 2.32 Top
#
# 15 Kled 51.74 2.18 Top
#
# 16 Quinn 50.99 2.01 Top
#
# 17 Sion 52.81 2.01 Top
#
# 18 Sett 49.47 5.79 Top
#
# 19 Lucian 48.31 7.42 Top
#
# 20 Garen 50.29 2.98 Top
#
# 21 Jayce 48.76 7.08 Top
#
# 22 Sylas 48.41 5.53 Top
#
# 23 Jax 49.4 3.7 Top
#
# 24 Irelia 47.43 7.24 Top
#
# 25 Wukong 50.75 2.5 Top
#
# 26 Rengar 50.52 2.16 Top
#
# 27 Heimerdinger 52.15 0.97 Top
#
# 28 Kayle 50.2 2.13 Top
#
# 29 Olaf 51.99 0.64 Top
#
# 30 Vayne 49.21 2.68 Top
#
# 31 Kennen 50.53 1.84 Top
#
# 32 Mordekaiser 47.76 4.12 Top
#
# 33 Nasus 50.18 1.98 Top
#
# 34 Warwick 50.93 1.04 Top
#
# 35 Yasuo 48.43 1.18 Top
#
# 36 Viktor 50.1 0.75 Top
#
# 37 Zac 49.28 1.12 Top
#
# 38 Yorick 51.28 0.6 Top
#
# 39 Riven 48.62 2.49 Top
#
# 40 Illaoi 47.82 1.63 Top
#
# 41 Yone 47.99 1.13 Top
#
# 42 Tryndamere 48.9 1.38 Top
#
# 43 Cho'Gath 50.63 0.81 Top
#
# 44 Singed 49.2 1.21 Top
#
# 45 Gragas 49.67 0.98 Top
#
# 46 Gangplank 46.67 1.86 Top
#
# 47 Gnar 48.73 0.98 Top
#
# 48 Urgot 47.4 1.4 Top
#
# 49 Rumble 46.8 1.46 Top
#
# 50 Vladimir 45.76 1.66 Top
#
# 51 Kalista 46.26 0.72 Top
#
# 52 Ryze 45.73 0.81 Top
#
# 1 Olaf 54.23 6.5 Jugle
#
# 2 Nunu & Willump 53.41 8.24 Jugle
#
# 3 Graves 49.95 21.43 Jugle
#
# 4 Kha'Zix 50.8 14.08 Jugle
#
# 5 Taliyah 52.47 8.57 Jugle
#
# 6 Elise 52.95 5.68 Jugle
#
# 7 Hecarim 51.03 10.17 Jugle
#
# 8 Fiddlesticks 53.64 3.23 Jugle
#
# 9 Ekko 50.64 9.22 Jugle
#
# 10 Evelynn 52.84 2.91 Jugle
#
# 11 Ivern 53.38 2.52 Jugle
#
# 12 Rek'Sai 51.06 4.2 Jugle
#
# 13 Lee Sin 47.84 22.98 Jugle
#
# 14 Shaco 50.45 3.9 Jugle
#
# 15 Kayn 47.11 9.73 Jugle
#
# 16 Rammus 50.62 3.0 Jugle
#
# 17 Kindred 49.15 7.06 Jugle
#
# 18 Udyr 51.92 2.58 Jugle
#
# 19 Lillia 48.87 6.32 Jugle
#
# 20 Poppy 51.4 2.19 Jugle
#
# 21 Karthus 51.21 1.77 Jugle
#
# 22 Master Yi 48.89 5.01 Jugle
#
# 23 Warwick 51.92 2.29 Jugle
#
# 24 Nidalee 48.87 5.49 Jugle
#
# 25 Vi 51.78 2.31 Jugle
#
# 26 Gragas 51.24 1.99 Jugle
#
# 27 Sejuani 51.13 1.8 Jugle
#
# 28 Skarner 52.27 0.9 Jugle
#
# 29 Xin Zhao 49.66 1.94 Jugle
#
# 30 Amumu 47.0 2.84 Jugle
#
# 31 Zac 47.34 3.38 Jugle
#
# 32 Wukong 51.14 0.71 Jugle
#
# 33 Volibear 49.25 0.95 Jugle
#
# 34 Jarvan IV 47.82 2.53 Jugle
#
# 35 Jax 47.46 1.03 Jugle
#
# 36 Nocturne 47.21 1.21 Jugle
#
# 37 Rengar 46.76 1.17 Jugle
#
# 38 Shyvana 47.1 1.13 Jugle
#
# 39 Dr. Mundo 46.33 0.68 Jugle
#
# 40 Trundle 45.85 0.51 Jugle
#
# 1 Anivia 51.95 11.12 Mid
#
# 2 Pantheon 53.38 4.3 Mid
#
# 3 Fizz 51.36 7.74 Mid
#
# 4 Zed 50.37 11.51 Mid
#
# 5 Galio 53.12 5.24 Mid
#
# 6 Ekko 51.86 7.34 Mid
#
# 7 Malphite 53.48 1.39 Mid
#
# 8 Viktor 50.83 7.77 Mid
#
# 9 Yasuo 49.69 8.9 Mid
#
# 10 Katarina 48.98 10.76 Mid
#
# 11 Yone 49.48 7.19 Mid
#
# 12 Akali 47.9 9.3 Mid
#
# 13 Talon 51.6 3.67 Mid
#
# 14 Malzahar 52.2 2.11 Mid
#
# 15 Sylas 48.35 9.66 Mid
#
# 16 Zoe 50.16 4.17 Mid
#
# 17 Twisted Fate 50.23 6.03 Mid
#
# 18 LeBlanc 48.82 4.27 Mid
#
# 19 Renekton 51.75 1.2 Mid
#
# 20 Annie 52.93 1.24 Mid
#
# 21 Xerath 50.1 2.88 Mid
#
# 22 Garen 52.84 0.79 Mid
#
# 23 Kassadin 50.36 2.32 Mid
#
# 24 Neeko 53.52 0.84 Mid
#
# 25 Lucian 47.61 7.6 Mid
#
# 26 Cassiopeia 50.58 2.31 Mid
#
# 27 Morgana 50.98 0.88 Mid
#
# 28 Ahri 50.49 3.34 Mid
#
# 29 Orianna 48.94 4.88 Mid
#
# 30 Pyke 51.62 0.77 Mid
#
# 31 Diana 49.22 3.95 Mid
#
# 32 Rumble 51.45 1.48 Mid
#
# 33 Swain 52.29 0.53 Mid
#
# 34 Aurelion Sol 52.45 0.87 Mid
#
# 35 Tristana 51.78 0.93 Mid
#
# 36 Jayce 50.02 1.63 Mid
#
# 37 Nunu & Willump 50.18 0.76 Mid
#
# 38 Sett 49.98 1.42 Mid
#
# 39 Brand 51.67 0.67 Mid
#
# 40 Qiyana 49.53 1.61 Mid
#
# 41 Vladimir 48.32 2.5 Mid
#
# 42 Lissandra 50.54 1.19 Mid
#
# 43 Lux 49.35 1.66 Mid
#
# 44 Irelia 45.25 3.69 Mid
#
# 45 Syndra 46.99 2.13 Mid
#
# 46 Ryze 47.04 1.53 Mid
#
# 47 Azir 47.52 1.24 Mid
#
# 48 Nocturne 47.83 0.5 Mid
#
# 49 Mordekaiser 46.97 0.56 Mid
#
# 50 Corki 47.88 0.65 Mid
#
# 51 Veigar 47.08 0.61 Mid
#
# 1 Jhin 51.66 32.62 Ad
#
# 2 Kai'Sa 51.7 34.68 Ad
#
# 3 Miss Fortune 52.14 13.51 Ad
#
# 4 Samira 49.02 11.52 Ad
#
# 5 Vayne 51.09 7.84 Ad
#
# 6 Ashe 50.57 10.34 Ad
#
# 7 Lucian 49.09 15.69 Ad
#
# 8 Tristana 52.16 5.01 Ad
#
# 9 Swain 54.43 1.04 Ad
#
# 10 Ezreal 47.17 31.07 Ad
#
# 11 Caitlyn 48.19 6.01 Ad
#
# 12 Draven 50.06 1.88 Ad
#
# 13 Yasuo 49.61 1.14 Ad
#
# 14 Aphelios 47.99 4.77 Ad
#
# 15 Kalista 49.36 1.64 Ad
#
# 16 Twitch 48.92 1.23 Ad
#
# 17 Senna 46.96 2.08 Ad
#
# 18 Xayah 45.83 4.82 Ad
#
# 19 Jinx 48.06 1.81 Ad
#
# 20 Varus 46.94 1.75 Ad
#
# 21 Sivir 47.62 0.85 Ad
#
# 22 Kog'Maw 47.48 0.76 Ad
#
# 1 Leona 52.91 12.28 Support
#
# 2 Maokai 52.75 11.71 Support
#
# 3 Thresh 52.02 18.4 Support
#
# 4 Pantheon 50.49 8.51 Support
#
# 5 Nautilus 51.4 7.19 Support
#
# 6 Blitzcrank 50.14 8.59 Support
#
# 7 Shaco 51.75 4.63 Support
#
# 8 Morgana 49.55 6.89 Support
#
# 9 Alistar 51.43 7.74 Support
#
# 10 Lulu 50.23 7.36 Support
#
# 11 Janna 52.16 4.84 Support
#
# 12 Xerath 49.76 7.76 Support
#
# 13 Yuumi 49.09 8.89 Support
#
# 14 Bard 52.1 3.43 Support
#
# 15 Ashe 49.55 6.68 Support
#
# 16 Pyke 48.53 6.93 Support
#
# 17 Anivia 51.27 1.18 Support
#
# 18 Zilean 51.48 2.75 Support
#
# 19 Seraphine 49.68 3.28 Support
#
# 20 Swain 49.52 3.12 Support
#
# 21 Nami 51.18 2.52 Support
#
# 22 Senna 48.43 4.7 Support
#
# 23 Rell 46.06 4.84 Support
#
# 24 Brand 49.11 3.17 Support
#
# 25 Galio 50.81 1.15 Support
#
# 26 Lux 48.69 5.25 Support
#
# 27 Zyra 50.12 1.97 Support
#
# 28 Braum 50.55 1.89 Support
#
# 29 Vel'Koz 50.69 1.68 Support
#
# 30 Rakan 49.19 2.77 Support
#
# 31 Soraka 48.52 3.03 Support
#
# 32 Sona 50.54 1.08 Support
#
# 33 Sett 45.65 4.94 Support
#
# 34 Shen 47.59 1.06 Support
#
# 35 Poppy 49.25 0.7 Support
#
# 36 Fiddlesticks 49.52 0.51 Support
#
# 37 Karma 45.82 3.04 Support
#
# 38 Taric 48.0 0.78 Support
#
# 39 Zac 47.41 0.7 Support
#
# 40 Gragas 49.08 0.55 Support
#
# 41 Miss Fortune 42.15 1.9 Support
#
# 42 Twitch 42.21 0.94 Support
#
# 43 Rumble 43.5 0.66 Support

# %%
# Way 2
for row in ws.iter_rows(min_row=ws.min_row, max_col=ws.max_column,
                        max_row=ws.max_row, values_only=True):
      print(row)
# Out:
# ('LoL Data From OP.GG', None, None, None, None)
# ('ranking', 'name', 'win_rate', 'pick_rate', 'position')
# ('1', 'Malphite', 52.59, 11.63, 'Top')
# ('2', 'Camille', 51.14, 14.7, 'Top')
# ('3', 'Pantheon', 52.98, 4.2, 'Top')
# ('4', 'Darius', 51.99, 6.02, 'Top')
# ('5', 'Aatrox', 50.37, 13.34, 'Top')
# ('6', 'Shen', 50.96, 7.91, 'Top')
# ('7', 'Maokai', 52.12, 3.57, 'Top')
# ('8', 'Ornn', 50.48, 10.03, 'Top')
# ('9', 'Akali', 49.1, 8.18, 'Top')
# ('10', 'Poppy', 51.94, 3.88, 'Top')
# ('11', 'Renekton', 49.8, 5.46, 'Top')
# ('12', 'Volibear', 51.05, 3.99, 'Top')
# ('13', 'Fiora', 49.48, 6.18, 'Top')
# ('14', 'Teemo', 50.98, 2.32, 'Top')
# ('15', 'Kled', 51.74, 2.18, 'Top')
# ('16', 'Quinn', 50.99, 2.01, 'Top')
# ('17', 'Sion', 52.81, 2.01, 'Top')
# ('18', 'Sett', 49.47, 5.79, 'Top')
# ('19', 'Lucian', 48.31, 7.42, 'Top')
# ('20', 'Garen', 50.29, 2.98, 'Top')
# ('21', 'Jayce', 48.76, 7.08, 'Top')
# ('22', 'Sylas', 48.41, 5.53, 'Top')
# ('23', 'Jax', 49.4, 3.7, 'Top')
# ('24', 'Irelia', 47.43, 7.24, 'Top')
# ('25', 'Wukong', 50.75, 2.5, 'Top')
# ('26', 'Rengar', 50.52, 2.16, 'Top')
# ('27', 'Heimerdinger', 52.15, 0.97, 'Top')
# ('28', 'Kayle', 50.2, 2.13, 'Top')
# ('29', 'Olaf', 51.99, 0.64, 'Top')
# ('30', 'Vayne', 49.21, 2.68, 'Top')
# ('31', 'Kennen', 50.53, 1.84, 'Top')
# ('32', 'Mordekaiser', 47.76, 4.12, 'Top')
# ('33', 'Nasus', 50.18, 1.98, 'Top')
# ('34', 'Warwick', 50.93, 1.04, 'Top')
# ('35', 'Yasuo', 48.43, 1.18, 'Top')
# ('36', 'Viktor', 50.1, 0.75, 'Top')
# ('37', 'Zac', 49.28, 1.12, 'Top')
# ('38', 'Yorick', 51.28, 0.6, 'Top')
# ('39', 'Riven', 48.62, 2.49, 'Top')
# ('40', 'Illaoi', 47.82, 1.63, 'Top')
# ('41', 'Yone', 47.99, 1.13, 'Top')
# ('42', 'Tryndamere', 48.9, 1.38, 'Top')
# ('43', "Cho'Gath", 50.63, 0.81, 'Top')
# ('44', 'Singed', 49.2, 1.21, 'Top')
# ('45', 'Gragas', 49.67, 0.98, 'Top')
# ('46', 'Gangplank', 46.67, 1.86, 'Top')
# ('47', 'Gnar', 48.73, 0.98, 'Top')
# ('48', 'Urgot', 47.4, 1.4, 'Top')
# ('49', 'Rumble', 46.8, 1.46, 'Top')
# ('50', 'Vladimir', 45.76, 1.66, 'Top')
# ('51', 'Kalista', 46.26, 0.72, 'Top')
# ('52', 'Ryze', 45.73, 0.81, 'Top')
# ('1', 'Olaf', 54.23, 6.5, 'Jugle')
# ('2', 'Nunu & Willump', 53.41, 8.24, 'Jugle')
# ('3', 'Graves', 49.95, 21.43, 'Jugle')
# ('4', "Kha'Zix", 50.8, 14.08, 'Jugle')
# ('5', 'Taliyah', 52.47, 8.57, 'Jugle')
# ('6', 'Elise', 52.95, 5.68, 'Jugle')
# ('7', 'Hecarim', 51.03, 10.17, 'Jugle')
# ('8', 'Fiddlesticks', 53.64, 3.23, 'Jugle')
# ('9', 'Ekko', 50.64, 9.22, 'Jugle')
# ('10', 'Evelynn', 52.84, 2.91, 'Jugle')
# ('11', 'Ivern', 53.38, 2.52, 'Jugle')
# ('12', "Rek'Sai", 51.06, 4.2, 'Jugle')
# ('13', 'Lee Sin', 47.84, 22.98, 'Jugle')
# ('14', 'Shaco', 50.45, 3.9, 'Jugle')
# ('15', 'Kayn', 47.11, 9.73, 'Jugle')
# ('16', 'Rammus', 50.62, 3.0, 'Jugle')
# ('17', 'Kindred', 49.15, 7.06, 'Jugle')
# ('18', 'Udyr', 51.92, 2.58, 'Jugle')
# ('19', 'Lillia', 48.87, 6.32, 'Jugle')
# ('20', 'Poppy', 51.4, 2.19, 'Jugle')
# ('21', 'Karthus', 51.21, 1.77, 'Jugle')
# ('22', 'Master Yi', 48.89, 5.01, 'Jugle')
# ('23', 'Warwick', 51.92, 2.29, 'Jugle')
# ('24', 'Nidalee', 48.87, 5.49, 'Jugle')
# ('25', 'Vi', 51.78, 2.31, 'Jugle')
# ('26', 'Gragas', 51.24, 1.99, 'Jugle')
# ('27', 'Sejuani', 51.13, 1.8, 'Jugle')
# ('28', 'Skarner', 52.27, 0.9, 'Jugle')
# ('29', 'Xin Zhao', 49.66, 1.94, 'Jugle')
# ('30', 'Amumu', 47.0, 2.84, 'Jugle')
# ('31', 'Zac', 47.34, 3.38, 'Jugle')
# ('32', 'Wukong', 51.14, 0.71, 'Jugle')
# ('33', 'Volibear', 49.25, 0.95, 'Jugle')
# ('34', 'Jarvan IV', 47.82, 2.53, 'Jugle')
# ('35', 'Jax', 47.46, 1.03, 'Jugle')
# ('36', 'Nocturne', 47.21, 1.21, 'Jugle')
# ('37', 'Rengar', 46.76, 1.17, 'Jugle')
# ('38', 'Shyvana', 47.1, 1.13, 'Jugle')
# ('39', 'Dr. Mundo', 46.33, 0.68, 'Jugle')
# ('40', 'Trundle', 45.85, 0.51, 'Jugle')
# ('1', 'Anivia', 51.95, 11.12, 'Mid')
# ('2', 'Pantheon', 53.38, 4.3, 'Mid')
# ('3', 'Fizz', 51.36, 7.74, 'Mid')
# ('4', 'Zed', 50.37, 11.51, 'Mid')
# ('5', 'Galio', 53.12, 5.24, 'Mid')
# ('6', 'Ekko', 51.86, 7.34, 'Mid')
# ('7', 'Malphite', 53.48, 1.39, 'Mid')
# ('8', 'Viktor', 50.83, 7.77, 'Mid')
# ('9', 'Yasuo', 49.69, 8.9, 'Mid')
# ('10', 'Katarina', 48.98, 10.76, 'Mid')
# ('11', 'Yone', 49.48, 7.19, 'Mid')
# ('12', 'Akali', 47.9, 9.3, 'Mid')
# ('13', 'Talon', 51.6, 3.67, 'Mid')
# ('14', 'Malzahar', 52.2, 2.11, 'Mid')
# ('15', 'Sylas', 48.35, 9.66, 'Mid')
# ('16', 'Zoe', 50.16, 4.17, 'Mid')
# ('17', 'Twisted Fate', 50.23, 6.03, 'Mid')
# ('18', 'LeBlanc', 48.82, 4.27, 'Mid')
# ('19', 'Renekton', 51.75, 1.2, 'Mid')
# ('20', 'Annie', 52.93, 1.24, 'Mid')
# ('21', 'Xerath', 50.1, 2.88, 'Mid')
# ('22', 'Garen', 52.84, 0.79, 'Mid')
# ('23', 'Kassadin', 50.36, 2.32, 'Mid')
# ('24', 'Neeko', 53.52, 0.84, 'Mid')
# ('25', 'Lucian', 47.61, 7.6, 'Mid')
# ('26', 'Cassiopeia', 50.58, 2.31, 'Mid')
# ('27', 'Morgana', 50.98, 0.88, 'Mid')
# ('28', 'Ahri', 50.49, 3.34, 'Mid')
# ('29', 'Orianna', 48.94, 4.88, 'Mid')
# ('30', 'Pyke', 51.62, 0.77, 'Mid')
# ('31', 'Diana', 49.22, 3.95, 'Mid')
# ('32', 'Rumble', 51.45, 1.48, 'Mid')
# ('33', 'Swain', 52.29, 0.53, 'Mid')
# ('34', 'Aurelion Sol', 52.45, 0.87, 'Mid')
# ('35', 'Tristana', 51.78, 0.93, 'Mid')
# ('36', 'Jayce', 50.02, 1.63, 'Mid')
# ('37', 'Nunu & Willump', 50.18, 0.76, 'Mid')
# ('38', 'Sett', 49.98, 1.42, 'Mid')
# ('39', 'Brand', 51.67, 0.67, 'Mid')
# ('40', 'Qiyana', 49.53, 1.61, 'Mid')
# ('41', 'Vladimir', 48.32, 2.5, 'Mid')
# ('42', 'Lissandra', 50.54, 1.19, 'Mid')
# ('43', 'Lux', 49.35, 1.66, 'Mid')
# ('44', 'Irelia', 45.25, 3.69, 'Mid')
# ('45', 'Syndra', 46.99, 2.13, 'Mid')
# ('46', 'Ryze', 47.04, 1.53, 'Mid')
# ('47', 'Azir', 47.52, 1.24, 'Mid')
# ('48', 'Nocturne', 47.83, 0.5, 'Mid')
# ('49', 'Mordekaiser', 46.97, 0.56, 'Mid')
# ('50', 'Corki', 47.88, 0.65, 'Mid')
# ('51', 'Veigar', 47.08, 0.61, 'Mid')
# ('1', 'Jhin', 51.66, 32.62, 'Ad')
# ('2', "Kai'Sa", 51.7, 34.68, 'Ad')
# ('3', 'Miss Fortune', 52.14, 13.51, 'Ad')
# ('4', 'Samira', 49.02, 11.52, 'Ad')
# ('5', 'Vayne', 51.09, 7.84, 'Ad')
# ('6', 'Ashe', 50.57, 10.34, 'Ad')
# ('7', 'Lucian', 49.09, 15.69, 'Ad')
# ('8', 'Tristana', 52.16, 5.01, 'Ad')
# ('9', 'Swain', 54.43, 1.04, 'Ad')
# ('10', 'Ezreal', 47.17, 31.07, 'Ad')
# ('11', 'Caitlyn', 48.19, 6.01, 'Ad')
# ('12', 'Draven', 50.06, 1.88, 'Ad')
# ('13', 'Yasuo', 49.61, 1.14, 'Ad')
# ('14', 'Aphelios', 47.99, 4.77, 'Ad')
# ('15', 'Kalista', 49.36, 1.64, 'Ad')
# ('16', 'Twitch', 48.92, 1.23, 'Ad')
# ('17', 'Senna', 46.96, 2.08, 'Ad')
# ('18', 'Xayah', 45.83, 4.82, 'Ad')
# ('19', 'Jinx', 48.06, 1.81, 'Ad')
# ('20', 'Varus', 46.94, 1.75, 'Ad')
# ('21', 'Sivir', 47.62, 0.85, 'Ad')
# ('22', "Kog'Maw", 47.48, 0.76, 'Ad')
# ('1', 'Leona', 52.91, 12.28, 'Support')
# ('2', 'Maokai', 52.75, 11.71, 'Support')
# ('3', 'Thresh', 52.02, 18.4, 'Support')
# ('4', 'Pantheon', 50.49, 8.51, 'Support')
# ('5', 'Nautilus', 51.4, 7.19, 'Support')
# ('6', 'Blitzcrank', 50.14, 8.59, 'Support')
# ('7', 'Shaco', 51.75, 4.63, 'Support')
# ('8', 'Morgana', 49.55, 6.89, 'Support')
# ('9', 'Alistar', 51.43, 7.74, 'Support')
# ('10', 'Lulu', 50.23, 7.36, 'Support')
# ('11', 'Janna', 52.16, 4.84, 'Support')
# ('12', 'Xerath', 49.76, 7.76, 'Support')
# ('13', 'Yuumi', 49.09, 8.89, 'Support')
# ('14', 'Bard', 52.1, 3.43, 'Support')
# ('15', 'Ashe', 49.55, 6.68, 'Support')
# ('16', 'Pyke', 48.53, 6.93, 'Support')
# ('17', 'Anivia', 51.27, 1.18, 'Support')
# ('18', 'Zilean', 51.48, 2.75, 'Support')
# ('19', 'Seraphine', 49.68, 3.28, 'Support')
# ('20', 'Swain', 49.52, 3.12, 'Support')
# ('21', 'Nami', 51.18, 2.52, 'Support')
# ('22', 'Senna', 48.43, 4.7, 'Support')
# ('23', 'Rell', 46.06, 4.84, 'Support')
# ('24', 'Brand', 49.11, 3.17, 'Support')
# ('25', 'Galio', 50.81, 1.15, 'Support')
# ('26', 'Lux', 48.69, 5.25, 'Support')
# ('27', 'Zyra', 50.12, 1.97, 'Support')
# ('28', 'Braum', 50.55, 1.89, 'Support')
# ('29', "Vel'Koz", 50.69, 1.68, 'Support')
# ('30', 'Rakan', 49.19, 2.77, 'Support')
# ('31', 'Soraka', 48.52, 3.03, 'Support')
# ('32', 'Sona', 50.54, 1.08, 'Support')
# ('33', 'Sett', 45.65, 4.94, 'Support')
# ('34', 'Shen', 47.59, 1.06, 'Support')
# ('35', 'Poppy', 49.25, 0.7, 'Support')
# ('36', 'Fiddlesticks', 49.52, 0.51, 'Support')
# ('37', 'Karma', 45.82, 3.04, 'Support')
# ('38', 'Taric', 48.0, 0.78, 'Support')
# ('39', 'Zac', 47.41, 0.7, 'Support')
# ('40', 'Gragas', 49.08, 0.55, 'Support')
# ('41', 'Miss Fortune', 42.15, 1.9, 'Support')
# ('42', 'Twitch', 42.21, 0.94, 'Support')
# ('43', 'Rumble', 43.5, 0.66, 'Support')

# %% [markdown]
# Coordinate
#
#     openpyxl.utils.cell.coordinate_from_string

# %%
for row in ws[3:ws.max_row]:
    for cell in row:
        xy = openpyxl.utils.cell.coordinate_from_string(cell.coordinate)
        print(xy[0], end = "")
        print(xy[1], end = " ")
# Out:
# A3 B3 C3 D3 E3 A4 B4 C4 D4 E4 A5 B5 C5 D5 E5 A6 B6 C6 D6 E6 A7 B7 C7 D7 E7 A8 B8 C8 D8 E8 A9 B9 C9 D9 E9 A10 B10 C10 D10 E10 A11 B11 C11 D11 E11 A12 B12 C12 D12 E12 A13 B13 C13 D13 E13 A14 B14 C14 D14 E14 A15 B15 C15 D15 E15 A16 B16 C16 D16 E16 A17 B17 C17 D17 E17 A18 B18 C18 D18 E18 A19 B19 C19 D19 E19 A20 B20 C20 D20 E20 A21 B21 C21 D21 E21 A22 B22 C22 D22 E22 A23 B23 C23 D23 E23 A24 B24 C24 D24 E24 A25 B25 C25 D25 E25 A26 B26 C26 D26 E26 A27 B27 C27 D27 E27 A28 B28 C28 D28 E28 A29 B29 C29 D29 E29 A30 B30 C30 D30 E30 A31 B31 C31 D31 E31 A32 B32 C32 D32 E32 A33 B33 C33 D33 E33 A34 B34 C34 D34 E34 A35 B35 C35 D35 E35 A36 B36 C36 D36 E36 A37 B37 C37 D37 E37 A38 B38 C38 D38 E38 A39 B39 C39 D39 E39 A40 B40 C40 D40 E40 A41 B41 C41 D41 E41 A42 B42 C42 D42 E42 A43 B43 C43 D43 E43 A44 B44 C44 D44 E44 A45 B45 C45 D45 E45 A46 B46 C46 D46 E46 A47 B47 C47 D47 E47 A48 B48 C48 D48 E48 A49 B49 C49 D49 E49 A50 B50 C50 D50 E50 A51 B51 C51 D51 E51 A52 B52 C52 D52 E52 A53 B53 C53 D53 E53 A54 B54 C54 D54 E54 A55 B55 C55 D55 E55 A56 B56 C56 D56 E56 A57 B57 C57 D57 E57 A58 B58 C58 D58 E58 A59 B59 C59 D59 E59 A60 B60 C60 D60 E60 A61 B61 C61 D61 E61 A62 B62 C62 D62 E62 A63 B63 C63 D63 E63 A64 B64 C64 D64 E64 A65 B65 C65 D65 E65 A66 B66 C66 D66 E66 A67 B67 C67 D67 E67 A68 B68 C68 D68 E68 A69 B69 C69 D69 E69 A70 B70 C70 D70 E70 A71 B71 C71 D71 E71 A72 B72 C72 D72 E72 A73 B73 C73 D73 E73 A74 B74 C74 D74 E74 A75 B75 C75 D75 E75 A76 B76 C76 D76 E76 A77 B77 C77 D77 E77 A78 B78 C78 D78 E78 A79 B79 C79 D79 E79 A80 B80 C80 D80 E80 A81 B81 C81 D81 E81 A82 B82 C82 D82 E82 A83 B83 C83 D83 E83 A84 B84 C84 D84 E84 A85 B85 C85 D85 E85 A86 B86 C86 D86 E86 A87 B87 C87 D87 E87 A88 B88 C88 D88 E88 A89 B89 C89 D89 E89 A90 B90 C90 D90 E90 A91 B91 C91 D91 E91 A92 B92 C92 D92 E92 A93 B93 C93 D93 E93 A94 B94 C94 D94 E94 A95 B95 C95 D95 E95 A96 B96 C96 D96 E96 A97 B97 C97 D97 E97 A98 B98 C98 D98 E98 A99 B99 C99 D99 E99 A100 B100 C100 D100 E100 A101 B101 C101 D101 E101 A102 B102 C102 D102 E102 A103 B103 C103 D103 E103 A104 B104 C104 D104 E104 A105 B105 C105 D105 E105 A106 B106 C106 D106 E106 A107 B107 C107 D107 E107 A108 B108 C108 D108 E108 A109 B109 C109 D109 E109 A110 B110 C110 D110 E110 A111 B111 C111 D111 E111 A112 B112 C112 D112 E112 A113 B113 C113 D113 E113 A114 B114 C114 D114 E114 A115 B115 C115 D115 E115 A116 B116 C116 D116 E116 A117 B117 C117 D117 E117 A118 B118 C118 D118 E118 A119 B119 C119 D119 E119 A120 B120 C120 D120 E120 A121 B121 C121 D121 E121 A122 B122 C122 D122 E122 A123 B123 C123 D123 E123 A124 B124 C124 D124 E124 A125 B125 C125 D125 E125 A126 B126 C126 D126 E126 A127 B127 C127 D127 E127 A128 B128 C128 D128 E128 A129 B129 C129 D129 E129 A130 B130 C130 D130 E130 A131 B131 C131 D131 E131 A132 B132 C132 D132 E132 A133 B133 C133 D133 E133 A134 B134 C134 D134 E134 A135 B135 C135 D135 E135 A136 B136 C136 D136 E136 A137 B137 C137 D137 E137 A138 B138 C138 D138 E138 A139 B139 C139 D139 E139 A140 B140 C140 D140 E140 A141 B141 C141 D141 E141 A142 B142 C142 D142 E142 A143 B143 C143 D143 E143 A144 B144 C144 D144 E144 A145 B145 C145 D145 E145 A146 B146 C146 D146 E146 A147 B147 C147 D147 E147 A148 B148 C148 D148 E148 A149 B149 C149 D149 E149 A150 B150 C150 D150 E150 A151 B151 C151 D151 E151 A152 B152 C152 D152 E152 A153 B153 C153 D153 E153 A154 B154 C154 D154 E154 A155 B155 C155 D155 E155 A156 B156 C156 D156 E156 A157 B157 C157 D157 E157 A158 B158 C158 D158 E158 A159 B159 C159 D159 E159 A160 B160 C160 D160 E160 A161 B161 C161 D161 E161 A162 B162 C162 D162 E162 A163 B163 C163 D163 E163 A164 B164 C164 D164 E164 A165 B165 C165 D165 E165 A166 B166 C166 D166 E166 A167 B167 C167 D167 E167 A168 B168 C168 D168 E168 A169 B169 C169 D169 E169 A170 B170 C170 D170 E170 A171 B171 C171 D171 E171 A172 B172 C172 D172 E172 A173 B173 C173 D173 E173 A174 B174 C174 D174 E174 A175 B175 C175 D175 E175 A176 B176 C176 D176 E176 A177 B177 C177 D177 E177 A178 B178 C178 D178 E178 A179 B179 C179 D179 E179 A180 B180 C180 D180 E180 A181 B181 C181 D181 E181 A182 B182 C182 D182 E182 A183 B183 C183 D183  ...

# %%
tuple(ws.columns)
# Out:
# ((<Cell 'LoL Data From OP.GG'.A1>,
#   <Cell 'LoL Data From OP.GG'.A2>,
#   <Cell 'LoL Data From OP.GG'.A3>,
#   <Cell 'LoL Data From OP.GG'.A4>,
#   <Cell 'LoL Data From OP.GG'.A5>,
#   <Cell 'LoL Data From OP.GG'.A6>,
#   <Cell 'LoL Data From OP.GG'.A7>,
#   <Cell 'LoL Data From OP.GG'.A8>,
#   <Cell 'LoL Data From OP.GG'.A9>,
#   <Cell 'LoL Data From OP.GG'.A10>,
#   <Cell 'LoL Data From OP.GG'.A11>,
#   <Cell 'LoL Data From OP.GG'.A12>,
#   <Cell 'LoL Data From OP.GG'.A13>,
#   <Cell 'LoL Data From OP.GG'.A14>,
#   <Cell 'LoL Data From OP.GG'.A15>,
#   <Cell 'LoL Data From OP.GG'.A16>,
#   <Cell 'LoL Data From OP.GG'.A17>,
#   <Cell 'LoL Data From OP.GG'.A18>,
#   <Cell 'LoL Data From OP.GG'.A19>,
#   <Cell 'LoL Data From OP.GG'.A20>,
#   <Cell 'LoL Data From OP.GG'.A21>,
#   <Cell 'LoL Data From OP.GG'.A22>,
#   <Cell 'LoL Data From OP.GG'.A23>,
#   <Cell 'LoL Data From OP.GG'.A24>,
#   <Cell 'LoL Data From OP.GG'.A25>,
#   <Cell 'LoL Data From OP.GG'.A26>,
#   <Cell 'LoL Data From OP.GG'.A27>,
#   <Cell 'LoL Data From OP.GG'.A28>,
#   <Cell 'LoL Data From OP.GG'.A29>,
#   <Cell 'LoL Data From OP.GG'.A30>,
#   <Cell 'LoL Data From OP.GG'.A31>,
#   <Cell 'LoL Data From OP.GG'.A32>,
#   <Cell 'LoL Data From OP.GG'.A33>,
#   <Cell 'LoL Data From OP.GG'.A34>,
#   <Cell 'LoL Data From OP.GG'.A35>,
#   <Cell 'LoL Data From OP.GG'.A36>,
#   <Cell 'LoL Data From OP.GG'.A37>,
#   <Cell 'LoL Data From OP.GG'.A38>,
#   <Cell 'LoL Data From OP.GG'.A39>,
#   <Cell 'LoL Data From OP.GG'.A40>,
#   <Cell 'LoL Data From OP.GG'.A41>,
#   <Cell 'LoL Data From OP.GG'.A42>,
#   <Cell 'LoL Data From OP.GG'.A43>,
#   <Cell 'LoL Data From OP.GG'.A44>,
#   <Cell 'LoL Data From OP.GG'.A45>,
#   <Cell 'LoL Data From OP.GG'.A46>,
#   <Cell 'LoL Data From OP.GG'.A47>,
#   <Cell 'LoL Data From OP.GG'.A48>,
#   <Cell 'LoL Data From OP.GG'.A49>,
#   <Cell 'LoL Data From OP.GG'.A50>,
#   <Cell 'LoL Data From OP.GG'.A51>,
#   <Cell 'LoL Data From OP.GG'.A52>,
#   <Cell 'LoL Data From OP.GG'.A53>,
#   <Cell 'LoL Data From OP.GG'.A54>,
#   <Cell 'LoL Data From OP.GG'.A55>,
#   <Cell 'LoL Data From OP.GG'.A56>,
#   <Cell 'LoL Data From OP.GG'.A57>,
#   <Cell 'LoL Data From OP.GG'.A58>,
#   <Cell 'LoL Data From OP.GG'.A59>,
#   <Cell 'LoL Data From OP.GG'.A60>,
#   <Cell 'LoL Data From OP.GG'.A61>,
#   <Cell 'LoL Data From OP.GG'.A62>,
#   <Cell 'LoL Data From OP.GG'.A63>,
#   <Cell 'LoL Data From OP.GG'.A64>,
#   <Cell 'LoL Data From OP.GG'.A65>,
#   <Cell 'LoL Data From OP.GG'.A66>,
#   <Cell 'LoL Data From OP.GG'.A67>,
#   <Cell 'LoL Data From OP.GG'.A68>,
#   <Cell 'LoL Data From OP.GG'.A69>,
#   <Cell 'LoL Data From OP.GG'.A70>,
#   <Cell 'LoL Data From OP.GG'.A71>,
#   <Cell 'LoL Data From OP.GG'.A72>,
#   <Cell 'LoL Data From OP.GG'.A73>,
#   <Cell 'LoL Data From OP.GG'.A74>,
#   <Cell 'LoL Data From OP.GG'.A75>,
#   <Cell 'LoL Data From OP.GG'.A76>,
#   <Cell 'LoL Data From OP.GG'.A77>,
#   <Cell 'LoL Data From OP.GG'.A78>,
#   <Cell 'LoL Data From OP.GG'.A79>,
#   <Cell 'LoL Data From OP.GG'.A80>,
#   <Cell 'LoL Data From OP.GG'.A81>,
#   <Cell 'LoL Data From OP.GG'.A82>,
#   <Cell 'LoL Data From OP.GG'.A83>,
#   <Cell 'LoL Data From OP.GG'.A84>,
#   <Cell 'LoL Data From OP.GG'.A85>,
#   <Cell 'LoL Data From OP.GG'.A86>,
#   <Cell 'LoL Data From OP.GG'.A87>,
#   <Cell 'LoL Data From OP.GG'.A88>,
#   <Cell 'LoL Data From OP.GG'.A89>,
#   <Cell 'LoL Data From OP.GG'.A90>,
#   <Cell 'LoL Data From OP.GG'.A91>,
#   <Cell 'LoL Data From OP.GG'.A92>,
#   <Cell 'LoL Data From OP.GG'.A93>,
#   <Cell 'LoL Data From OP.GG'.A94>,
#   <Cell 'LoL Data From OP.GG'.A95>,
#   <Cell 'LoL Data From OP.GG'.A96>,
#   <Cell 'LoL Data From OP.GG'.A97>,
#   <Cell 'LoL Data From OP.GG'.A98>,
#   <Cell 'LoL Data From OP.GG'.A99>,
#   <Cell 'LoL Data From OP.GG'.A100>,
#   <Cell 'LoL Data From OP.GG'.A101>,
#   <Cell 'LoL Data From OP.GG'.A102>,
#   <Cell 'LoL Data From OP.GG'.A103>,
#   <Cell 'LoL Data From OP.GG'.A104>,
#   <Cell 'LoL Data From OP.GG'.A105>,
#   <Cell 'LoL Data From OP.GG'.A106>,
#   <Cell 'LoL Data From OP.GG'.A107>,
#   <Cell 'LoL Data From OP.GG'.A108>,
#   <Cell 'LoL Data From OP.GG'.A109>,
#   <Cell 'LoL Data From OP.GG'.A110>,
#   <Cell 'LoL Data From OP.GG'.A111>,
#   <Cell 'LoL Data From OP.GG'.A112>,
#   <Cell 'LoL Data From OP.GG'.A113>,
#   <Cell 'LoL Data From OP.GG'.A114>,
#   <Cell 'LoL Data From OP.GG'.A115>,
#   <Cell 'LoL Data From OP.GG'.A116>,
#   <Cell 'LoL Data From OP.GG'.A117>,
#   <Cell 'LoL Data From OP.GG'.A118>,
#   <Cell 'LoL Data From OP.GG'.A119>,
#   <Cell 'LoL Data From OP.GG'.A120>,
#   <Cell 'LoL Data From OP.GG'.A121>,
#   <Cell 'LoL Data From OP.GG'.A122>,
#   <Cell 'LoL Data From OP.GG'.A123>,
#   <Cell 'LoL Data From OP.GG'.A124>,
#   <Cell 'LoL Data From OP.GG'.A125>,
#   <Cell 'LoL Data From OP.GG'.A126>,
#   <Cell 'LoL Data From OP.GG'.A127>,
#   <Cell 'LoL Data From OP.GG'.A128>,
#   <Cell 'LoL Data From OP.GG'.A129>,
#   <Cell 'LoL Data From OP.GG'.A130>,
#   <Cell 'LoL Data From OP.GG'.A131>,
#   <Cell 'LoL Data From OP.GG'.A132>,
#   <Cell 'LoL Data From OP.GG'.A133>,
#   <Cell 'LoL Data From OP.GG'.A134>,
#   <Cell 'LoL Data From OP.GG'.A135>,
#   <Cell 'LoL Data From OP.GG'.A136>,
#   <Cell 'LoL Data From OP.GG'.A137>,
#   <Cell 'LoL Data From OP.GG'.A138>,
#   <Cell 'LoL Data From OP.GG'.A139>,
#   <Cell 'LoL Data From OP.GG'.A140>,
#   <Cell 'LoL Data From OP.GG'.A141>,
#   <Cell 'LoL Data From OP.GG'.A142>,
#   <Cell 'LoL Data From OP.GG'.A143>,
#   <Cell 'LoL Data From OP.GG'.A144>,
#   <Cell 'LoL Data From OP.GG'.A145>,
#   <Cell 'LoL Data From OP.GG'.A146>,
#   <Cell 'LoL Data From OP.GG'.A147>,
#   <Cell 'LoL Data From OP.GG'.A148>,
#   <Cell 'LoL Data From OP.GG'.A149>,
#   <Cell 'LoL Data From OP.GG'.A150>,
#   <Cell 'LoL Data From OP.GG'.A151>,
#   <Cell 'LoL Data From OP.GG'.A152>,
#   <Cell 'LoL Data From OP.GG'.A153>,
#   <Cell 'LoL Data From OP.GG'.A154>,
#   <Cell 'LoL Data From OP.GG'.A155>,
#   <Cell 'LoL Data From OP.GG'.A156>,
#   <Cell 'LoL Data From OP.GG'.A157>,
#   <Cell 'LoL Data From OP.GG'.A158>,
#   <Cell 'LoL Data From OP.GG'.A159>,
#   <Cell 'LoL Data From OP.GG'.A160>,
#   <Cell 'LoL Data From OP.GG'.A161>,
#   <Cell 'LoL Data From OP.GG'.A162>,
#   <Cell 'LoL Data From OP.GG'.A163>,
#   <Cell 'LoL Data From OP.GG'.A164>,
#   <Cell 'LoL Data From OP.GG'.A165>,
#   <Cell 'LoL Data From OP.GG'.A166>,
#   <Cell 'LoL Data From OP.GG'.A167>,
#   <Cell 'LoL Data From OP.GG'.A168>,
#   <Cell 'LoL Data From OP.GG'.A169>,
#   <Cell 'LoL Data From OP.GG'.A170>,
#   <Cell 'LoL Data From OP.GG'.A171>,
#   <Cell 'LoL Data From OP.GG'.A172>,
#   <Cell 'LoL Data From OP.GG'.A173>,
#   <Cell 'LoL Data From OP.GG'.A174>,
#   <Cell 'LoL Data From OP.GG'.A175>,
#   <Cell 'LoL Data From OP.GG'.A176>,
#   <Cell 'LoL Data From OP.GG'.A177>,
#   <Cell 'LoL Data From OP.GG'.A178>,
#   <Cell 'LoL Data From OP.GG'.A179>,
#   <Cell 'LoL Data From OP.GG'.A180>,
#   <Cell 'LoL Data From OP.GG'.A181>,
#   <Cell 'LoL Data From OP.GG'.A182>,
#   <Cell 'LoL Data From OP.GG'.A183>,
#   <Cell 'LoL Data From OP.GG'.A184>,
#   <Cell 'LoL Data From OP.GG'.A185>,
#   <Cell 'LoL Data From OP.GG'.A186>,
#   <Cell 'LoL Data From OP.GG'.A187>,
#   <Cell 'LoL Data From OP.GG'.A188>,
#   <Cell 'LoL Data From OP.GG'.A189>,
#   <Cell 'LoL Data From OP.GG'.A190>,
#   <Cell 'LoL Data From OP.GG'.A191>,
#   <Cell 'LoL Data From OP.GG'.A192>,
#   <Cell 'LoL Data From OP.GG'.A193>,
#   <Cell 'LoL Data From OP.GG'.A194>,
#   <Cell 'LoL Data From OP.GG'.A195>,
#   <Cell 'LoL Data From OP.GG'.A196>,
#   <Cell 'LoL Data From OP.GG'.A197>,
#   <Cell 'LoL Data From OP.GG'.A198>,
#   <Cell 'LoL Data From OP.GG'.A199>,
#   <Cell 'LoL Data From OP.GG'.A200>,
#   <Cell 'LoL Data From OP.GG'.A201>,
#   <Cell 'LoL Data From OP.GG'.A202>,
#   <Cell 'LoL Data From OP.GG'.A203>,
#   <Cell 'LoL Data From OP.GG'.A204>,
#   <Cell 'LoL Data From OP.GG'.A205>,
#   <Cell 'LoL Data From OP.GG'.A206>,
#   <Cell 'LoL Data From OP.GG'.A207>,
#   <Cell 'LoL Data From OP.GG'.A208>,
#   <Cell 'LoL Data From OP.GG'.A209>,
#   <Cell 'LoL Data From OP.GG'.A210>),
#  (<Cell 'LoL Data From OP.GG'.B1>,
#   <Cell 'LoL Data From OP.GG'.B2>,
#   <Cell 'LoL Data From OP.GG'.B3>,
#   <Cell 'LoL Data From OP.GG'.B4>,
#   <Cell 'LoL Data From OP.GG'.B5>,
#   <Cell 'LoL Data From OP.GG'.B6>,
#   <Cell 'LoL Data From OP.GG'.B7>,
#   <Cell 'LoL Data From OP.GG'.B8>,
#   <Cell 'LoL Data From OP.GG'.B9>,
#   <Cell 'LoL Data From OP.GG'.B10>,
#   <Cell 'LoL Data From OP.GG'.B11>,
#   <Cell 'LoL Data From OP.GG'.B12>,
#   <Cell 'LoL Data From OP.GG'.B13>,
#   <Cell 'LoL Data From OP.GG'.B14>,
#   <Cell 'LoL Data From OP.GG'.B15>,
#   <Cell 'LoL Data From OP.GG'.B16>,
#   <Cell 'LoL Data From OP.GG'.B17>,
#   <Cell 'LoL Data From OP.GG'.B18>,
#   <Cell 'LoL Data From OP.GG'.B19>,
#   <Cell 'LoL Data From OP.GG'.B20>,
#   <Cell 'LoL Data From OP.GG'.B21>,
#   <Cell 'LoL Data From OP.GG'.B22>,
#   <Cell 'LoL Data From OP.GG'.B23>,
#   <Cell 'LoL Data From OP.GG'.B24>,
#   <Cell 'LoL Data From OP.GG'.B25>,
#   <Cell 'LoL Data From OP.GG'.B26>,
#   <Cell 'LoL Data From OP.GG'.B27>,
#   <Cell 'LoL Data From OP.GG'.B28>,
#   <Cell 'LoL Data From OP.GG'.B29>,
#   <Cell 'LoL Data From OP.GG'.B30>,
#   <Cell 'LoL Data From OP.GG'.B31>,
#   <Cell 'LoL Data From OP.GG'.B32>,
#   <Cell 'LoL Data From OP.GG'.B33>,
#   <Cell 'LoL Data From OP.GG'.B34>,
#   <Cell 'LoL Data From OP.GG'.B35>,
#   <Cell 'LoL Data From OP.GG'.B36>,
#   <Cell 'LoL Data From OP.GG'.B37>,
#   <Cell 'LoL Data From OP.GG'.B38>,
#   <Cell 'LoL Data From OP.GG'.B39>,
#   <Cell 'LoL Data From OP.GG'.B40>,
#   <Cell 'LoL Data From OP.GG'.B41>,
#   <Cell 'LoL Data From OP.GG'.B42>,
#   <Cell 'LoL Data From OP.GG'.B43>,
#   <Cell 'LoL Data From OP.GG'.B44>,
#   <Cell 'LoL Data From OP.GG'.B45>,
#   <Cell 'LoL Data From OP.GG'.B46>,
#   <Cell 'LoL Data From OP.GG'.B47>,
#   <Cell 'LoL Data From OP.GG'.B48>,
#   <Cell 'LoL Data From OP.GG'.B49>,
#   <Cell 'LoL Data From OP.GG'.B50>,
#   <Cell 'LoL Data From OP.GG'.B51>,
#   <Cell 'LoL Data From OP.GG'.B52>,
#   <Cell 'LoL Data From OP.GG'.B53>,
#   <Cell 'LoL Data From OP.GG'.B54>,
#   <Cell 'LoL Data From OP.GG'.B55>,
#   <Cell 'LoL Data From OP.GG'.B56>,
#   <Cell 'LoL Data From OP.GG'.B57>,
#   <Cell 'LoL Data From OP.GG'.B58>,
#   <Cell 'LoL Data From OP.GG'.B59>,
#   <Cell 'LoL Data From OP.GG'.B60>,
#   <Cell 'LoL Data From OP.GG'.B61>,
#   <Cell 'LoL Data From OP.GG'.B62>,
#   <Cell 'LoL Data From OP.GG'.B63>,
#   <Cell 'LoL Data From OP.GG'.B64>,
#   <Cell 'LoL Data From OP.GG'.B65>,
#   <Cell 'LoL Data From OP.GG'.B66>,
#   <Cell 'LoL Data From OP.GG'.B67>,
#   <Cell 'LoL Data From OP.GG'.B68>,
#   <Cell 'LoL Data From OP.GG'.B69>,
#   <Cell 'LoL Data From OP.GG'.B70>,
#   <Cell 'LoL Data From OP.GG'.B71>,
#   <Cell 'LoL Data From OP.GG'.B72>,
#   <Cell 'LoL Data From OP.GG'.B73>,
#   <Cell 'LoL Data From OP.GG'.B74>,
#   <Cell 'LoL Data From OP.GG'.B75>,
#   <Cell 'LoL Data From OP.GG'.B76>,
#   <Cell 'LoL Data From OP.GG'.B77>,
#   <Cell 'LoL Data From OP.GG'.B78>,
#   <Cell 'LoL Data From OP.GG'.B79>,
#   <Cell 'LoL Data From OP.GG'.B80>,
#   <Cell 'LoL Data From OP.GG'.B81>,
#   <Cell 'LoL Data From OP.GG'.B82>,
#   <Cell 'LoL Data From OP.GG'.B83>,
#   <Cell 'LoL Data From OP.GG'.B84>,
#   <Cell 'LoL Data From OP.GG'.B85>,
#   <Cell 'LoL Data From OP.GG'.B86>,
#   <Cell 'LoL Data From OP.GG'.B87>,
#   <Cell 'LoL Data From OP.GG'.B88>,
#   <Cell 'LoL Data From OP.GG'.B89>,
#   <Cell 'LoL Data From OP.GG'.B90>,
#   <Cell 'LoL Data From OP.GG'.B91>,
#   <Cell 'LoL Data From OP.GG'.B92>,
#   <Cell 'LoL Data From OP.GG'.B93>,
#   <Cell 'LoL Data From OP.GG'.B94>,
#   <Cell 'LoL Data From OP.GG'.B95>,
#   <Cell 'LoL Data From OP.GG'.B96>,
#   <Cell 'LoL Data From OP.GG'.B97>,
#   <Cell 'LoL Data From OP.GG'.B98>,
#   <Cell 'LoL Data From OP.GG'.B99>,
#   <Cell 'LoL Data From OP.GG'.B100>,
#   <Cell 'LoL Data From OP.GG'.B101>,
#   <Cell 'LoL Data From OP.GG'.B102>,
#   <Cell 'LoL Data From OP.GG'.B103>,
#   <Cell 'LoL Data From OP.GG'.B104>,
#   <Cell 'LoL Data From OP.GG'.B105>,
#   <Cell 'LoL Data From OP.GG'.B106>,
#   <Cell 'LoL Data From OP.GG'.B107>,
#   <Cell 'LoL Data From OP.GG'.B108>,
#   <Cell 'LoL Data From OP.GG'.B109>,
#   <Cell 'LoL Data From OP.GG'.B110>,
#   <Cell 'LoL Data From OP.GG'.B111>,
#   <Cell 'LoL Data From OP.GG'.B112>,
#   <Cell 'LoL Data From OP.GG'.B113>,
#   <Cell 'LoL Data From OP.GG'.B114>,
#   <Cell 'LoL Data From OP.GG'.B115>,
#   <Cell 'LoL Data From OP.GG'.B116>,
#   <Cell 'LoL Data From OP.GG'.B117>,
#   <Cell 'LoL Data From OP.GG'.B118>,
#   <Cell 'LoL Data From OP.GG'.B119>,
#   <Cell 'LoL Data From OP.GG'.B120>,
#   <Cell 'LoL Data From OP.GG'.B121>,
#   <Cell 'LoL Data From OP.GG'.B122>,
#   <Cell 'LoL Data From OP.GG'.B123>,
#   <Cell 'LoL Data From OP.GG'.B124>,
#   <Cell 'LoL Data From OP.GG'.B125>,
#   <Cell 'LoL Data From OP.GG'.B126>,
#   <Cell 'LoL Data From OP.GG'.B127>,
#   <Cell 'LoL Data From OP.GG'.B128>,
#   <Cell 'LoL Data From OP.GG'.B129>,
#   <Cell 'LoL Data From OP.GG'.B130>,
#   <Cell 'LoL Data From OP.GG'.B131>,
#   <Cell 'LoL Data From OP.GG'.B132>,
#   <Cell 'LoL Data From OP.GG'.B133>,
#   <Cell 'LoL Data From OP.GG'.B134>,
#   <Cell 'LoL Data From OP.GG'.B135>,
#   <Cell 'LoL Data From OP.GG'.B136>,
#   <Cell 'LoL Data From OP.GG'.B137>,
#   <Cell 'LoL Data From OP.GG'.B138>,
#   <Cell 'LoL Data From OP.GG'.B139>,
#   <Cell 'LoL Data From OP.GG'.B140>,
#   <Cell 'LoL Data From OP.GG'.B141>,
#   <Cell 'LoL Data From OP.GG'.B142>,
#   <Cell 'LoL Data From OP.GG'.B143>,
#   <Cell 'LoL Data From OP.GG'.B144>,
#   <Cell 'LoL Data From OP.GG'.B145>,
#   <Cell 'LoL Data From OP.GG'.B146>,
#   <Cell 'LoL Data From OP.GG'.B147>,
#   <Cell 'LoL Data From OP.GG'.B148>,
#   <Cell 'LoL Data From OP.GG'.B149>,
#   <Cell 'LoL Data From OP.GG'.B150>,
#   <Cell 'LoL Data From OP.GG'.B151>,
#   <Cell 'LoL Data From OP.GG'.B152>,
#   <Cell 'LoL Data From OP.GG'.B153>,
#   <Cell 'LoL Data From OP.GG'.B154>,
#   <Cell 'LoL Data From OP.GG'.B155>,
#   <Cell 'LoL Data From OP.GG'.B156>,
#   <Cell 'LoL Data From OP.GG'.B157>,
#   <Cell 'LoL Data From OP.GG'.B158>,
#   <Cell 'LoL Data From OP.GG'.B159>,
#   <Cell 'LoL Data From OP.GG'.B160>,
#   <Cell 'LoL Data From OP.GG'.B161>,
#   <Cell 'LoL Data From OP.GG'.B162>,
#   <Cell 'LoL Data From OP.GG'.B163>,
#   <Cell 'LoL Data From OP.GG'.B164>,
#   <Cell 'LoL Data From OP.GG'.B165>,
#   <Cell 'LoL Data From OP.GG'.B166>,
#   <Cell 'LoL Data From OP.GG'.B167>,
#   <Cell 'LoL Data From OP.GG'.B168>,
#   <Cell 'LoL Data From OP.GG'.B169>,
#   <Cell 'LoL Data From OP.GG'.B170>,
#   <Cell 'LoL Data From OP.GG'.B171>,
#   <Cell 'LoL Data From OP.GG'.B172>,
#   <Cell 'LoL Data From OP.GG'.B173>,
#   <Cell 'LoL Data From OP.GG'.B174>,
#   <Cell 'LoL Data From OP.GG'.B175>,
#   <Cell 'LoL Data From OP.GG'.B176>,
#   <Cell 'LoL Data From OP.GG'.B177>,
#   <Cell 'LoL Data From OP.GG'.B178>,
#   <Cell 'LoL Data From OP.GG'.B179>,
#   <Cell 'LoL Data From OP.GG'.B180>,
#   <Cell 'LoL Data From OP.GG'.B181>,
#   <Cell 'LoL Data From OP.GG'.B182>,
#   <Cell 'LoL Data From OP.GG'.B183>,
#   <Cell 'LoL Data From OP.GG'.B184>,
#   <Cell 'LoL Data From OP.GG'.B185>,
#   <Cell 'LoL Data From OP.GG'.B186>,
#   <Cell 'LoL Data From OP.GG'.B187>,
#   <Cell 'LoL Data From OP.GG'.B188>,
#   <Cell 'LoL Data From OP.GG'.B189>,
#   <Cell 'LoL Data From OP.GG'.B190>,
#   <Cell 'LoL Data From OP.GG'.B191>,
#   <Cell 'LoL Data From OP.GG'.B192>,
#   <Cell 'LoL Data From OP.GG'.B193>,
#   <Cell 'LoL Data From OP.GG'.B194>,
#   <Cell 'LoL Data From OP.GG'.B195>,
#   <Cell 'LoL Data From OP.GG'.B196>,
#   <Cell 'LoL Data From OP.GG'.B197>,
#   <Cell 'LoL Data From OP.GG'.B198>,
#   <Cell 'LoL Data From OP.GG'.B199>,
#   <Cell 'LoL Data From OP.GG'.B200>,
#   <Cell 'LoL Data From OP.GG'.B201>,
#   <Cell 'LoL Data From OP.GG'.B202>,
#   <Cell 'LoL Data From OP.GG'.B203>,
#   <Cell 'LoL Data From OP.GG'.B204>,
#   <Cell 'LoL Data From OP.GG'.B205>,
#   <Cell 'LoL Data From OP.GG'.B206>,
#   <Cell 'LoL Data From OP.GG'.B207>,
#   <Cell 'LoL Data From OP.GG'.B208>,
#   <Cell 'LoL Data From OP.GG'.B209>,
#   <Cell 'LoL Data From OP.GG'.B210>),
#  (<Cell 'LoL Data From OP.GG'.C1>,
#   <Cell 'LoL Data From OP.GG'.C2>,
#   <Cell 'LoL Data From OP.GG'.C3>,
#   <Cell 'LoL Data From OP.GG'.C4>,
#   <Cell 'LoL Data From OP.GG'.C5>,
#   <Cell 'LoL Data From OP.GG'.C6>,
#   <Cell 'LoL Data From OP.GG'.C7>,
#   <Cell 'LoL Data From OP.GG'.C8>,
#   <Cell 'LoL Data From OP.GG'.C9>,
#   <Cell 'LoL Data From OP.GG'.C10>,
#   <Cell 'LoL Data From OP.GG'.C11>,
#   <Cell 'LoL Data From OP.GG'.C12>,
#   <Cell 'LoL Data From OP.GG'.C13>,
#   <Cell 'LoL Data From OP.GG'.C14>,
#   <Cell 'LoL Data From OP.GG'.C15>,
#   <Cell 'LoL Data From OP.GG'.C16>,
#   <Cell 'LoL Data From OP.GG'.C17>,
#   <Cell 'LoL Data From OP.GG'.C18>,
#   <Cell 'LoL Data From OP.GG'.C19>,
#   <Cell 'LoL Data From OP.GG'.C20>,
#   <Cell 'LoL Data From OP.GG'.C21>,
#   <Cell 'LoL Data From OP.GG'.C22>,
#   <Cell 'LoL Data From OP.GG'.C23>,
#   <Cell 'LoL Data From OP.GG'.C24>,
#   <Cell 'LoL Data From OP.GG'.C25>,
#   <Cell 'LoL Data From OP.GG'.C26>,
#   <Cell 'LoL Data From OP.GG'.C27>,
#   <Cell 'LoL Data From OP.GG'.C28>,
#   <Cell 'LoL Data From OP.GG'.C29>,
#   <Cell 'LoL Data From OP.GG'.C30>,
#   <Cell 'LoL Data From OP.GG'.C31>,
#   <Cell 'LoL Data From OP.GG'.C32>,
#   <Cell 'LoL Data From OP.GG'.C33>,
#   <Cell 'LoL Data From OP.GG'.C34>,
#   <Cell 'LoL Data From OP.GG'.C35>,
#   <Cell 'LoL Data From OP.GG'.C36>,
#   <Cell 'LoL Data From OP.GG'.C37>,
#   <Cell 'LoL Data From OP.GG'.C38>,
#   <Cell 'LoL Data From OP.GG'.C39>,
#   <Cell 'LoL Data From OP.GG'.C40>,
#   <Cell 'LoL Data From OP.GG'.C41>,
#   <Cell 'LoL Data From OP.GG'.C42>,
#   <Cell 'LoL Data From OP.GG'.C43>,
#   <Cell 'LoL Data From OP.GG'.C44>,
#   <Cell 'LoL Data From OP.GG'.C45>,
#   <Cell 'LoL Data From OP.GG'.C46>,
#   <Cell 'LoL Data From OP.GG'.C47>,
#   <Cell 'LoL Data From OP.GG'.C48>,
#   <Cell 'LoL Data From OP.GG'.C49>,
#   <Cell 'LoL Data From OP.GG'.C50>,
#   <Cell 'LoL Data From OP.GG'.C51>,
#   <Cell 'LoL Data From OP.GG'.C52>,
#   <Cell 'LoL Data From OP.GG'.C53>,
#   <Cell 'LoL Data From OP.GG'.C54>,
#   <Cell 'LoL Data From OP.GG'.C55>,
#   <Cell 'LoL Data From OP.GG'.C56>,
#   <Cell 'LoL Data From OP.GG'.C57>,
#   <Cell 'LoL Data From OP.GG'.C58>,
#   <Cell 'LoL Data From OP.GG'.C59>,
#   <Cell 'LoL Data From OP.GG'.C60>,
#   <Cell 'LoL Data From OP.GG'.C61>,
#   <Cell 'LoL Data From OP.GG'.C62>,
#   <Cell 'LoL Data From OP.GG'.C63>,
#   <Cell 'LoL Data From OP.GG'.C64>,
#   <Cell 'LoL Data From OP.GG'.C65>,
#   <Cell 'LoL Data From OP.GG'.C66>,
#   <Cell 'LoL Data From OP.GG'.C67>,
#   <Cell 'LoL Data From OP.GG'.C68>,
#   <Cell 'LoL Data From OP.GG'.C69>,
#   <Cell 'LoL Data From OP.GG'.C70>,
#   <Cell 'LoL Data From OP.GG'.C71>,
#   <Cell 'LoL Data From OP.GG'.C72>,
#   <Cell 'LoL Data From OP.GG'.C73>,
#   <Cell 'LoL Data From OP.GG'.C74>,
#   <Cell 'LoL Data From OP.GG'.C75>,
#   <Cell 'LoL Data From OP.GG'.C76>,
#   <Cell 'LoL Data From OP.GG'.C77>,
#   <Cell 'LoL Data From OP.GG'.C78>,
#   <Cell 'LoL Data From OP.GG'.C79>,
#   <Cell 'LoL Data From OP.GG'.C80>,
#   <Cell 'LoL Data From OP.GG'.C81>,
#   <Cell 'LoL Data From OP.GG'.C82>,
#   <Cell 'LoL Data From OP.GG'.C83>,
#   <Cell 'LoL Data From OP.GG'.C84>,
#   <Cell 'LoL Data From OP.GG'.C85>,
#   <Cell 'LoL Data From OP.GG'.C86>,
#   <Cell 'LoL Data From OP.GG'.C87>,
#   <Cell 'LoL Data From OP.GG'.C88>,
#   <Cell 'LoL Data From OP.GG'.C89>,
#   <Cell 'LoL Data From OP.GG'.C90>,
#   <Cell 'LoL Data From OP.GG'.C91>,
#   <Cell 'LoL Data From OP.GG'.C92>,
#   <Cell 'LoL Data From OP.GG'.C93>,
#   <Cell 'LoL Data From OP.GG'.C94>,
#   <Cell 'LoL Data From OP.GG'.C95>,
#   <Cell 'LoL Data From OP.GG'.C96>,
#   <Cell 'LoL Data From OP.GG'.C97>,
#   <Cell 'LoL Data From OP.GG'.C98>,
#   <Cell 'LoL Data From OP.GG'.C99>,
#   <Cell 'LoL Data From OP.GG'.C100>,
#   <Cell 'LoL Data From OP.GG'.C101>,
#   <Cell 'LoL Data From OP.GG'.C102>,
#   <Cell 'LoL Data From OP.GG'.C103>,
#   <Cell 'LoL Data From OP.GG'.C104>,
#   <Cell 'LoL Data From OP.GG'.C105>,
#   <Cell 'LoL Data From OP.GG'.C106>,
#   <Cell 'LoL Data From OP.GG'.C107>,
#   <Cell 'LoL Data From OP.GG'.C108>,
#   <Cell 'LoL Data From OP.GG'.C109>,
#   <Cell 'LoL Data From OP.GG'.C110>,
#   <Cell 'LoL Data From OP.GG'.C111>,
#   <Cell 'LoL Data From OP.GG'.C112>,
#   <Cell 'LoL Data From OP.GG'.C113>,
#   <Cell 'LoL Data From OP.GG'.C114>,
#   <Cell 'LoL Data From OP.GG'.C115>,
#   <Cell 'LoL Data From OP.GG'.C116>,
#   <Cell 'LoL Data From OP.GG'.C117>,
#   <Cell 'LoL Data From OP.GG'.C118>,
#   <Cell 'LoL Data From OP.GG'.C119>,
#   <Cell 'LoL Data From OP.GG'.C120>,
#   <Cell 'LoL Data From OP.GG'.C121>,
#   <Cell 'LoL Data From OP.GG'.C122>,
#   <Cell 'LoL Data From OP.GG'.C123>,
#   <Cell 'LoL Data From OP.GG'.C124>,
#   <Cell 'LoL Data From OP.GG'.C125>,
#   <Cell 'LoL Data From OP.GG'.C126>,
#   <Cell 'LoL Data From OP.GG'.C127>,
#   <Cell 'LoL Data From OP.GG'.C128>,
#   <Cell 'LoL Data From OP.GG'.C129>,
#   <Cell 'LoL Data From OP.GG'.C130>,
#   <Cell 'LoL Data From OP.GG'.C131>,
#   <Cell 'LoL Data From OP.GG'.C132>,
#   <Cell 'LoL Data From OP.GG'.C133>,
#   <Cell 'LoL Data From OP.GG'.C134>,
#   <Cell 'LoL Data From OP.GG'.C135>,
#   <Cell 'LoL Data From OP.GG'.C136>,
#   <Cell 'LoL Data From OP.GG'.C137>,
#   <Cell 'LoL Data From OP.GG'.C138>,
#   <Cell 'LoL Data From OP.GG'.C139>,
#   <Cell 'LoL Data From OP.GG'.C140>,
#   <Cell 'LoL Data From OP.GG'.C141>,
#   <Cell 'LoL Data From OP.GG'.C142>,
#   <Cell 'LoL Data From OP.GG'.C143>,
#   <Cell 'LoL Data From OP.GG'.C144>,
#   <Cell 'LoL Data From OP.GG'.C145>,
#   <Cell 'LoL Data From OP.GG'.C146>,
#   <Cell 'LoL Data From OP.GG'.C147>,
#   <Cell 'LoL Data From OP.GG'.C148>,
#   <Cell 'LoL Data From OP.GG'.C149>,
#   <Cell 'LoL Data From OP.GG'.C150>,
#   <Cell 'LoL Data From OP.GG'.C151>,
#   <Cell 'LoL Data From OP.GG'.C152>,
#   <Cell 'LoL Data From OP.GG'.C153>,
#   <Cell 'LoL Data From OP.GG'.C154>,
#   <Cell 'LoL Data From OP.GG'.C155>,
#   <Cell 'LoL Data From OP.GG'.C156>,
#   <Cell 'LoL Data From OP.GG'.C157>,
#   <Cell 'LoL Data From OP.GG'.C158>,
#   <Cell 'LoL Data From OP.GG'.C159>,
#   <Cell 'LoL Data From OP.GG'.C160>,
#   <Cell 'LoL Data From OP.GG'.C161>,
#   <Cell 'LoL Data From OP.GG'.C162>,
#   <Cell 'LoL Data From OP.GG'.C163>,
#   <Cell 'LoL Data From OP.GG'.C164>,
#   <Cell 'LoL Data From OP.GG'.C165>,
#   <Cell 'LoL Data From OP.GG'.C166>,
#   <Cell 'LoL Data From OP.GG'.C167>,
#   <Cell 'LoL Data From OP.GG'.C168>,
#   <Cell 'LoL Data From OP.GG'.C169>,
#   <Cell 'LoL Data From OP.GG'.C170>,
#   <Cell 'LoL Data From OP.GG'.C171>,
#   <Cell 'LoL Data From OP.GG'.C172>,
#   <Cell 'LoL Data From OP.GG'.C173>,
#   <Cell 'LoL Data From OP.GG'.C174>,
#   <Cell 'LoL Data From OP.GG'.C175>,
#   <Cell 'LoL Data From OP.GG'.C176>,
#   <Cell 'LoL Data From OP.GG'.C177>,
#   <Cell 'LoL Data From OP.GG'.C178>,
#   <Cell 'LoL Data From OP.GG'.C179>,
#   <Cell 'LoL Data From OP.GG'.C180>,
#   <Cell 'LoL Data From OP.GG'.C181>,
#   <Cell 'LoL Data From OP.GG'.C182>,
#   <Cell 'LoL Data From OP.GG'.C183>,
#   <Cell 'LoL Data From OP.GG'.C184>,
#   <Cell 'LoL Data From OP.GG'.C185>,
#   <Cell 'LoL Data From OP.GG'.C186>,
#   <Cell 'LoL Data From OP.GG'.C187>,
#   <Cell 'LoL Data From OP.GG'.C188>,
#   <Cell 'LoL Data From OP.GG'.C189>,
#   <Cell 'LoL Data From OP.GG'.C190>,
#   <Cell 'LoL Data From OP.GG'.C191>,
#   <Cell 'LoL Data From OP.GG'.C192>,
#   <Cell 'LoL Data From OP.GG'.C193>,
#   <Cell 'LoL Data From OP.GG'.C194>,
#   <Cell 'LoL Data From OP.GG'.C195>,
#   <Cell 'LoL Data From OP.GG'.C196>,
#   <Cell 'LoL Data From OP.GG'.C197>,
#   <Cell 'LoL Data From OP.GG'.C198>,
#   <Cell 'LoL Data From OP.GG'.C199>,
#   <Cell 'LoL Data From OP.GG'.C200>,
#   <Cell 'LoL Data From OP.GG'.C201>,
#   <Cell 'LoL Data From OP.GG'.C202>,
#   <Cell 'LoL Data From OP.GG'.C203>,
#   <Cell 'LoL Data From OP.GG'.C204>,
#   <Cell 'LoL Data From OP.GG'.C205>,
#   <Cell 'LoL Data From OP.GG'.C206>,
#   <Cell 'LoL Data From OP.GG'.C207>,
#   <Cell 'LoL Data From OP.GG'.C208>,
#   <Cell 'LoL Data From OP.GG'.C209>,
#   <Cell 'LoL Data From OP.GG'.C210>),
#  (<Cell 'LoL Data From OP.GG'.D1>,
#   <Cell 'LoL Data From OP.GG'.D2>,
#   <Cell 'LoL Data From OP.GG'.D3>,
#   <Cell 'LoL Data From OP.GG'.D4>,
#   <Cell 'LoL Data From OP.GG'.D5>,
#   <Cell 'LoL Data From OP.GG'.D6>,
#   <Cell 'LoL Data From OP.GG'.D7>,
#   <Cell 'LoL Data From OP.GG'.D8>,
#   <Cell 'LoL Data From OP.GG'.D9>,
#   <Cell 'LoL Data From OP.GG'.D10>,
#   <Cell 'LoL Data From OP.GG'.D11>,
#   <Cell 'LoL Data From OP.GG'.D12>,
#   <Cell 'LoL Data From OP.GG'.D13>,
#   <Cell 'LoL Data From OP.GG'.D14>,
#   <Cell 'LoL Data From OP.GG'.D15>,
#   <Cell 'LoL Data From OP.GG'.D16>,
#   <Cell 'LoL Data From OP.GG'.D17>,
#   <Cell 'LoL Data From OP.GG'.D18>,
#   <Cell 'LoL Data From OP.GG'.D19>,
#   <Cell 'LoL Data From OP.GG'.D20>,
#   <Cell 'LoL Data From OP.GG'.D21>,
#   <Cell 'LoL Data From OP.GG'.D22>,
#   <Cell 'LoL Data From OP.GG'.D23>,
#   <Cell 'LoL Data From OP.GG'.D24>,
#   <Cell 'LoL Data From OP.GG'.D25>,
#   <Cell 'LoL Data From OP.GG'.D26>,
#   <Cell 'LoL Data From OP.GG'.D27>,
#   <Cell 'LoL Data From OP.GG'.D28>,
#   <Cell 'LoL Data From OP.GG'.D29>,
#   <Cell 'LoL Data From OP.GG'.D30>,
#   <Cell 'LoL Data From OP.GG'.D31>,
#   <Cell 'LoL Data From OP.GG'.D32>,
#   <Cell 'LoL Data From OP.GG'.D33>,
#   <Cell 'LoL Data From OP.GG'.D34>,
#   <Cell 'LoL Data From OP.GG'.D35>,
#   <Cell 'LoL Data From OP.GG'.D36>,
#   <Cell 'LoL Data From OP.GG'.D37>,
#   <Cell 'LoL Data From OP.GG'.D38>,
#   <Cell 'LoL Data From OP.GG'.D39>,
#   <Cell 'LoL Data From OP.GG'.D40>,
#   <Cell 'LoL Data From OP.GG'.D41>,
#   <Cell 'LoL Data From OP.GG'.D42>,
#   <Cell 'LoL Data From OP.GG'.D43>,
#   <Cell 'LoL Data From OP.GG'.D44>,
#   <Cell 'LoL Data From OP.GG'.D45>,
#   <Cell 'LoL Data From OP.GG'.D46>,
#   <Cell 'LoL Data From OP.GG'.D47>,
#   <Cell 'LoL Data From OP.GG'.D48>,
#   <Cell 'LoL Data From OP.GG'.D49>,
#   <Cell 'LoL Data From OP.GG'.D50>,
#   <Cell 'LoL Data From OP.GG'.D51>,
#   <Cell 'LoL Data From OP.GG'.D52>,
#   <Cell 'LoL Data From OP.GG'.D53>,
#   <Cell 'LoL Data From OP.GG'.D54>,
#   <Cell 'LoL Data From OP.GG'.D55>,
#   <Cell 'LoL Data From OP.GG'.D56>,
#   <Cell 'LoL Data From OP.GG'.D57>,
#   <Cell 'LoL Data From OP.GG'.D58>,
#   <Cell 'LoL Data From OP.GG'.D59>,
#   <Cell 'LoL Data From OP.GG'.D60>,
#   <Cell 'LoL Data From OP.GG'.D61>,
#   <Cell 'LoL Data From OP.GG'.D62>,
#   <Cell 'LoL Data From OP.GG'.D63>,
#   <Cell 'LoL Data From OP.GG'.D64>,
#   <Cell 'LoL Data From OP.GG'.D65>,
#   <Cell 'LoL Data From OP.GG'.D66>,
#   <Cell 'LoL Data From OP.GG'.D67>,
#   <Cell 'LoL Data From OP.GG'.D68>,
#   <Cell 'LoL Data From OP.GG'.D69>,
#   <Cell 'LoL Data From OP.GG'.D70>,
#   <Cell 'LoL Data From OP.GG'.D71>,
#   <Cell 'LoL Data From OP.GG'.D72>,
#   <Cell 'LoL Data From OP.GG'.D73>,
#   <Cell 'LoL Data From OP.GG'.D74>,
#   <Cell 'LoL Data From OP.GG'.D75>,
#   <Cell 'LoL Data From OP.GG'.D76>,
#   <Cell 'LoL Data From OP.GG'.D77>,
#   <Cell 'LoL Data From OP.GG'.D78>,
#   <Cell 'LoL Data From OP.GG'.D79>,
#   <Cell 'LoL Data From OP.GG'.D80>,
#   <Cell 'LoL Data From OP.GG'.D81>,
#   <Cell 'LoL Data From OP.GG'.D82>,
#   <Cell 'LoL Data From OP.GG'.D83>,
#   <Cell 'LoL Data From OP.GG'.D84>,
#   <Cell 'LoL Data From OP.GG'.D85>,
#   <Cell 'LoL Data From OP.GG'.D86>,
#   <Cell 'LoL Data From OP.GG'.D87>,
#   <Cell 'LoL Data From OP.GG'.D88>,
#   <Cell 'LoL Data From OP.GG'.D89>,
#   <Cell 'LoL Data From OP.GG'.D90>,
#   <Cell 'LoL Data From OP.GG'.D91>,
#   <Cell 'LoL Data From OP.GG'.D92>,
#   <Cell 'LoL Data From OP.GG'.D93>,
#   <Cell 'LoL Data From OP.GG'.D94>,
#   <Cell 'LoL Data From OP.GG'.D95>,
#   <Cell 'LoL Data From OP.GG'.D96>,
#   <Cell 'LoL Data From OP.GG'.D97>,
#   <Cell 'LoL Data From OP.GG'.D98>,
#   <Cell 'LoL Data From OP.GG'.D99>,
#   <Cell 'LoL Data From OP.GG'.D100>,
#   <Cell 'LoL Data From OP.GG'.D101>,
#   <Cell 'LoL Data From OP.GG'.D102>,
#   <Cell 'LoL Data From OP.GG'.D103>,
#   <Cell 'LoL Data From OP.GG'.D104>,
#   <Cell 'LoL Data From OP.GG'.D105>,
#   <Cell 'LoL Data From OP.GG'.D106>,
#   <Cell 'LoL Data From OP.GG'.D107>,
#   <Cell 'LoL Data From OP.GG'.D108>,
#   <Cell 'LoL Data From OP.GG'.D109>,
#   <Cell 'LoL Data From OP.GG'.D110>,
#   <Cell 'LoL Data From OP.GG'.D111>,
#   <Cell 'LoL Data From OP.GG'.D112>,
#   <Cell 'LoL Data From OP.GG'.D113>,
#   <Cell 'LoL Data From OP.GG'.D114>,
#   <Cell 'LoL Data From OP.GG'.D115>,
#   <Cell 'LoL Data From OP.GG'.D116>,
#   <Cell 'LoL Data From OP.GG'.D117>,
#   <Cell 'LoL Data From OP.GG'.D118>,
#   <Cell 'LoL Data From OP.GG'.D119>,
#   <Cell 'LoL Data From OP.GG'.D120>,
#   <Cell 'LoL Data From OP.GG'.D121>,
#   <Cell 'LoL Data From OP.GG'.D122>,
#   <Cell 'LoL Data From OP.GG'.D123>,
#   <Cell 'LoL Data From OP.GG'.D124>,
#   <Cell 'LoL Data From OP.GG'.D125>,
#   <Cell 'LoL Data From OP.GG'.D126>,
#   <Cell 'LoL Data From OP.GG'.D127>,
#   <Cell 'LoL Data From OP.GG'.D128>,
#   <Cell 'LoL Data From OP.GG'.D129>,
#   <Cell 'LoL Data From OP.GG'.D130>,
#   <Cell 'LoL Data From OP.GG'.D131>,
#   <Cell 'LoL Data From OP.GG'.D132>,
#   <Cell 'LoL Data From OP.GG'.D133>,
#   <Cell 'LoL Data From OP.GG'.D134>,
#   <Cell 'LoL Data From OP.GG'.D135>,
#   <Cell 'LoL Data From OP.GG'.D136>,
#   <Cell 'LoL Data From OP.GG'.D137>,
#   <Cell 'LoL Data From OP.GG'.D138>,
#   <Cell 'LoL Data From OP.GG'.D139>,
#   <Cell 'LoL Data From OP.GG'.D140>,
#   <Cell 'LoL Data From OP.GG'.D141>,
#   <Cell 'LoL Data From OP.GG'.D142>,
#   <Cell 'LoL Data From OP.GG'.D143>,
#   <Cell 'LoL Data From OP.GG'.D144>,
#   <Cell 'LoL Data From OP.GG'.D145>,
#   <Cell 'LoL Data From OP.GG'.D146>,
#   <Cell 'LoL Data From OP.GG'.D147>,
#   <Cell 'LoL Data From OP.GG'.D148>,
#   <Cell 'LoL Data From OP.GG'.D149>,
#   <Cell 'LoL Data From OP.GG'.D150>,
#   <Cell 'LoL Data From OP.GG'.D151>,
#   <Cell 'LoL Data From OP.GG'.D152>,
#   <Cell 'LoL Data From OP.GG'.D153>,
#   <Cell 'LoL Data From OP.GG'.D154>,
#   <Cell 'LoL Data From OP.GG'.D155>,
#   <Cell 'LoL Data From OP.GG'.D156>,
#   <Cell 'LoL Data From OP.GG'.D157>,
#   <Cell 'LoL Data From OP.GG'.D158>,
#   <Cell 'LoL Data From OP.GG'.D159>,
#   <Cell 'LoL Data From OP.GG'.D160>,
#   <Cell 'LoL Data From OP.GG'.D161>,
#   <Cell 'LoL Data From OP.GG'.D162>,
#   <Cell 'LoL Data From OP.GG'.D163>,
#   <Cell 'LoL Data From OP.GG'.D164>,
#   <Cell 'LoL Data From OP.GG'.D165>,
#   <Cell 'LoL Data From OP.GG'.D166>,
#   <Cell 'LoL Data From OP.GG'.D167>,
#   <Cell 'LoL Data From OP.GG'.D168>,
#   <Cell 'LoL Data From OP.GG'.D169>,
#   <Cell 'LoL Data From OP.GG'.D170>,
#   <Cell 'LoL Data From OP.GG'.D171>,
#   <Cell 'LoL Data From OP.GG'.D172>,
#   <Cell 'LoL Data From OP.GG'.D173>,
#   <Cell 'LoL Data From OP.GG'.D174>,
#   <Cell 'LoL Data From OP.GG'.D175>,
#   <Cell 'LoL Data From OP.GG'.D176>,
#   <Cell 'LoL Data From OP.GG'.D177>,
#   <Cell 'LoL Data From OP.GG'.D178>,
#   <Cell 'LoL Data From OP.GG'.D179>,
#   <Cell 'LoL Data From OP.GG'.D180>,
#   <Cell 'LoL Data From OP.GG'.D181>,
#   <Cell 'LoL Data From OP.GG'.D182>,
#   <Cell 'LoL Data From OP.GG'.D183>,
#   <Cell 'LoL Data From OP.GG'.D184>,
#   <Cell 'LoL Data From OP.GG'.D185>,
#   <Cell 'LoL Data From OP.GG'.D186>,
#   <Cell 'LoL Data From OP.GG'.D187>,
#   <Cell 'LoL Data From OP.GG'.D188>,
#   <Cell 'LoL Data From OP.GG'.D189>,
#   <Cell 'LoL Data From OP.GG'.D190>,
#   <Cell 'LoL Data From OP.GG'.D191>,
#   <Cell 'LoL Data From OP.GG'.D192>,
#   <Cell 'LoL Data From OP.GG'.D193>,
#   <Cell 'LoL Data From OP.GG'.D194>,
#   <Cell 'LoL Data From OP.GG'.D195>,
#   <Cell 'LoL Data From OP.GG'.D196>,
#   <Cell 'LoL Data From OP.GG'.D197>,
#   <Cell 'LoL Data From OP.GG'.D198>,
#   <Cell 'LoL Data From OP.GG'.D199>,
#   <Cell 'LoL Data From OP.GG'.D200>,
#   <Cell 'LoL Data From OP.GG'.D201>,
#   <Cell 'LoL Data From OP.GG'.D202>,
#   <Cell 'LoL Data From OP.GG'.D203>,
#   <Cell 'LoL Data From OP.GG'.D204>,
#   <Cell 'LoL Data From OP.GG'.D205>,
#   <Cell 'LoL Data From OP.GG'.D206>,
#   <Cell 'LoL Data From OP.GG'.D207>,
#   <Cell 'LoL Data From OP.GG'.D208>,
#   <Cell 'LoL Data From OP.GG'.D209>,
#   <Cell 'LoL Data From OP.GG'.D210>),
#  (<Cell 'LoL Data From OP.GG'.E1>,
#   <Cell 'LoL Data From OP.GG'.E2>,
#   <Cell 'LoL Data From OP.GG'.E3>,
#   <Cell 'LoL Data From OP.GG'.E4>,
#   <Cell 'LoL Data From OP.GG'.E5>,
#   <Cell 'LoL Data From OP.GG'.E6>,
#   <Cell 'LoL Data From OP.GG'.E7>,
#   <Cell 'LoL Data From OP.GG'.E8>,
#   <Cell 'LoL Data From OP.GG'.E9>,
#   <Cell 'LoL Data From OP.GG'.E10>,
#   <Cell 'LoL Data From OP.GG'.E11>,
#   <Cell 'LoL Data From OP.GG'.E12>,
#   <Cell 'LoL Data From OP.GG'.E13>,
#   <Cell 'LoL Data From OP.GG'.E14>,
#   <Cell 'LoL Data From OP.GG'.E15>,
#   <Cell 'LoL Data From OP.GG'.E16>,
#   <Cell 'LoL Data From OP.GG'.E17>,
#   <Cell 'LoL Data From OP.GG'.E18>,
#   <Cell 'LoL Data From OP.GG'.E19>,
#   <Cell 'LoL Data From OP.GG'.E20>,
#   <Cell 'LoL Data From OP.GG'.E21>,
#   <Cell 'LoL Data From OP.GG'.E22>,
#   <Cell 'LoL Data From OP.GG'.E23>,
#   <Cell 'LoL Data From OP.GG'.E24>,
#   <Cell 'LoL Data From OP.GG'.E25>,
#   <Cell 'LoL Data From OP.GG'.E26>,
#   <Cell 'LoL Data From OP.GG'.E27>,
#   <Cell 'LoL Data From OP.GG'.E28>,
#   <Cell 'LoL Data From OP.GG'.E29>,
#   <Cell 'LoL Data From OP.GG'.E30>,
#   <Cell 'LoL Data From OP.GG'.E31>,
#   <Cell 'LoL Data From OP.GG'.E32>,
#   <Cell 'LoL Data From OP.GG'.E33>,
#   <Cell 'LoL Data From OP.GG'.E34>,
#   <Cell 'LoL Data From OP.GG'.E35>,
#   <Cell 'LoL Data From OP.GG'.E36>,
#   <Cell 'LoL Data From OP.GG'.E37>,
#   <Cell 'LoL Data From OP.GG'.E38>,
#   <Cell 'LoL Data From OP.GG'.E39>,
#   <Cell 'LoL Data From OP.GG'.E40>,
#   <Cell 'LoL Data From OP.GG'.E41>,
#   <Cell 'LoL Data From OP.GG'.E42>,
#   <Cell 'LoL Data From OP.GG'.E43>,
#   <Cell 'LoL Data From OP.GG'.E44>,
#   <Cell 'LoL Data From OP.GG'.E45>,
#   <Cell 'LoL Data From OP.GG'.E46>,
#   <Cell 'LoL Data From OP.GG'.E47>,
#   <Cell 'LoL Data From OP.GG'.E48>,
#   <Cell 'LoL Data From OP.GG'.E49>,
#   <Cell 'LoL Data From OP.GG'.E50>,
#   <Cell 'LoL Data From OP.GG'.E51>,
#   <Cell 'LoL Data From OP.GG'.E52>,
#   <Cell 'LoL Data From OP.GG'.E53>,
#   <Cell 'LoL Data From OP.GG'.E54>,
#   <Cell 'LoL Data From OP.GG'.E55>,
#   <Cell 'LoL Data From OP.GG'.E56>,
#   <Cell 'LoL Data From OP.GG'.E57>,
#   <Cell 'LoL Data From OP.GG'.E58>,
#   <Cell 'LoL Data From OP.GG'.E59>,
#   <Cell 'LoL Data From OP.GG'.E60>,
#   <Cell 'LoL Data From OP.GG'.E61>,
#   <Cell 'LoL Data From OP.GG'.E62>,
#   <Cell 'LoL Data From OP.GG'.E63>,
#   <Cell 'LoL Data From OP.GG'.E64>,
#   <Cell 'LoL Data From OP.GG'.E65>,
#   <Cell 'LoL Data From OP.GG'.E66>,
#   <Cell 'LoL Data From OP.GG'.E67>,
#   <Cell 'LoL Data From OP.GG'.E68>,
#   <Cell 'LoL Data From OP.GG'.E69>,
#   <Cell 'LoL Data From OP.GG'.E70>,
#   <Cell 'LoL Data From OP.GG'.E71>,
#   <Cell 'LoL Data From OP.GG'.E72>,
#   <Cell 'LoL Data From OP.GG'.E73>,
#   <Cell 'LoL Data From OP.GG'.E74>,
#   <Cell 'LoL Data From OP.GG'.E75>,
#   <Cell 'LoL Data From OP.GG'.E76>,
#   <Cell 'LoL Data From OP.GG'.E77>,
#   <Cell 'LoL Data From OP.GG'.E78>,
#   <Cell 'LoL Data From OP.GG'.E79>,
#   <Cell 'LoL Data From OP.GG'.E80>,
#   <Cell 'LoL Data From OP.GG'.E81>,
#   <Cell 'LoL Data From OP.GG'.E82>,
#   <Cell 'LoL Data From OP.GG'.E83>,
#   <Cell 'LoL Data From OP.GG'.E84>,
#   <Cell 'LoL Data From OP.GG'.E85>,
#   <Cell 'LoL Data From OP.GG'.E86>,
#   <Cell 'LoL Data From OP.GG'.E87>,
#   <Cell 'LoL Data From OP.GG'.E88>,
#   <Cell 'LoL Data From OP.GG'.E89>,
#   <Cell 'LoL Data From OP.GG'.E90>,
#   <Cell 'LoL Data From OP.GG'.E91>,
#   <Cell 'LoL Data From OP.GG'.E92>,
#   <Cell 'LoL Data From OP.GG'.E93>,
#   <Cell 'LoL Data From OP.GG'.E94>,
#   <Cell 'LoL Data From OP.GG'.E95>,
#   <Cell 'LoL Data From OP.GG'.E96>,
#   <Cell 'LoL Data From OP.GG'.E97>,
#   <Cell 'LoL Data From OP.GG'.E98>,
#   <Cell 'LoL Data From OP.GG'.E99>,
#   <Cell 'LoL Data From OP.GG'.E100>,
#   <Cell 'LoL Data From OP.GG'.E101>,
#   <Cell 'LoL Data From OP.GG'.E102>,
#   <Cell 'LoL Data From OP.GG'.E103>,
#   <Cell 'LoL Data From OP.GG'.E104>,
#   <Cell 'LoL Data From OP.GG'.E105>,
#   <Cell 'LoL Data From OP.GG'.E106>,
#   <Cell 'LoL Data From OP.GG'.E107>,
#   <Cell 'LoL Data From OP.GG'.E108>,
#   <Cell 'LoL Data From OP.GG'.E109>,
#   <Cell 'LoL Data From OP.GG'.E110>,
#   <Cell 'LoL Data From OP.GG'.E111>,
#   <Cell 'LoL Data From OP.GG'.E112>,
#   <Cell 'LoL Data From OP.GG'.E113>,
#   <Cell 'LoL Data From OP.GG'.E114>,
#   <Cell 'LoL Data From OP.GG'.E115>,
#   <Cell 'LoL Data From OP.GG'.E116>,
#   <Cell 'LoL Data From OP.GG'.E117>,
#   <Cell 'LoL Data From OP.GG'.E118>,
#   <Cell 'LoL Data From OP.GG'.E119>,
#   <Cell 'LoL Data From OP.GG'.E120>,
#   <Cell 'LoL Data From OP.GG'.E121>,
#   <Cell 'LoL Data From OP.GG'.E122>,
#   <Cell 'LoL Data From OP.GG'.E123>,
#   <Cell 'LoL Data From OP.GG'.E124>,
#   <Cell 'LoL Data From OP.GG'.E125>,
#   <Cell 'LoL Data From OP.GG'.E126>,
#   <Cell 'LoL Data From OP.GG'.E127>,
#   <Cell 'LoL Data From OP.GG'.E128>,
#   <Cell 'LoL Data From OP.GG'.E129>,
#   <Cell 'LoL Data From OP.GG'.E130>,
#   <Cell 'LoL Data From OP.GG'.E131>,
#   <Cell 'LoL Data From OP.GG'.E132>,
#   <Cell 'LoL Data From OP.GG'.E133>,
#   <Cell 'LoL Data From OP.GG'.E134>,
#   <Cell 'LoL Data From OP.GG'.E135>,
#   <Cell 'LoL Data From OP.GG'.E136>,
#   <Cell 'LoL Data From OP.GG'.E137>,
#   <Cell 'LoL Data From OP.GG'.E138>,
#   <Cell 'LoL Data From OP.GG'.E139>,
#   <Cell 'LoL Data From OP.GG'.E140>,
#   <Cell 'LoL Data From OP.GG'.E141>,
#   <Cell 'LoL Data From OP.GG'.E142>,
#   <Cell 'LoL Data From OP.GG'.E143>,
#   <Cell 'LoL Data From OP.GG'.E144>,
#   <Cell 'LoL Data From OP.GG'.E145>,
#   <Cell 'LoL Data From OP.GG'.E146>,
#   <Cell 'LoL Data From OP.GG'.E147>,
#   <Cell 'LoL Data From OP.GG'.E148>,
#   <Cell 'LoL Data From OP.GG'.E149>,
#   <Cell 'LoL Data From OP.GG'.E150>,
#   <Cell 'LoL Data From OP.GG'.E151>,
#   <Cell 'LoL Data From OP.GG'.E152>,
#   <Cell 'LoL Data From OP.GG'.E153>,
#   <Cell 'LoL Data From OP.GG'.E154>,
#   <Cell 'LoL Data From OP.GG'.E155>,
#   <Cell 'LoL Data From OP.GG'.E156>,
#   <Cell 'LoL Data From OP.GG'.E157>,
#   <Cell 'LoL Data From OP.GG'.E158>,
#   <Cell 'LoL Data From OP.GG'.E159>,
#   <Cell 'LoL Data From OP.GG'.E160>,
#   <Cell 'LoL Data From OP.GG'.E161>,
#   <Cell 'LoL Data From OP.GG'.E162>,
#   <Cell 'LoL Data From OP.GG'.E163>,
#   <Cell 'LoL Data From OP.GG'.E164>,
#   <Cell 'LoL Data From OP.GG'.E165>,
#   <Cell 'LoL Data From OP.GG'.E166>,
#   <Cell 'LoL Data From OP.GG'.E167>,
#   <Cell 'LoL Data From OP.GG'.E168>,
#   <Cell 'LoL Data From OP.GG'.E169>,
#   <Cell 'LoL Data From OP.GG'.E170>,
#   <Cell 'LoL Data From OP.GG'.E171>,
#   <Cell 'LoL Data From OP.GG'.E172>,
#   <Cell 'LoL Data From OP.GG'.E173>,
#   <Cell 'LoL Data From OP.GG'.E174>,
#   <Cell 'LoL Data From OP.GG'.E175>,
#   <Cell 'LoL Data From OP.GG'.E176>,
#   <Cell 'LoL Data From OP.GG'.E177>,
#   <Cell 'LoL Data From OP.GG'.E178>,
#   <Cell 'LoL Data From OP.GG'.E179>,
#   <Cell 'LoL Data From OP.GG'.E180>,
#   <Cell 'LoL Data From OP.GG'.E181>,
#   <Cell 'LoL Data From OP.GG'.E182>,
#   <Cell 'LoL Data From OP.GG'.E183>,
#   <Cell 'LoL Data From OP.GG'.E184>,
#   <Cell 'LoL Data From OP.GG'.E185>,
#   <Cell 'LoL Data From OP.GG'.E186>,
#   <Cell 'LoL Data From OP.GG'.E187>,
#   <Cell 'LoL Data From OP.GG'.E188>,
#   <Cell 'LoL Data From OP.GG'.E189>,
#   <Cell 'LoL Data From OP.GG'.E190>,
#   <Cell 'LoL Data From OP.GG'.E191>,
#   <Cell 'LoL Data From OP.GG'.E192>,
#   <Cell 'LoL Data From OP.GG'.E193>,
#   <Cell 'LoL Data From OP.GG'.E194>,
#   <Cell 'LoL Data From OP.GG'.E195>,
#   <Cell 'LoL Data From OP.GG'.E196>,
#   <Cell 'LoL Data From OP.GG'.E197>,
#   <Cell 'LoL Data From OP.GG'.E198>,
#   <Cell 'LoL Data From OP.GG'.E199>,
#   <Cell 'LoL Data From OP.GG'.E200>,
#   <Cell 'LoL Data From OP.GG'.E201>,
#   <Cell 'LoL Data From OP.GG'.E202>,
#   <Cell 'LoL Data From OP.GG'.E203>,
#   <Cell 'LoL Data From OP.GG'.E204>,
#   <Cell 'LoL Data From OP.GG'.E205>,
#   <Cell 'LoL Data From OP.GG'.E206>,
#   <Cell 'LoL Data From OP.GG'.E207>,
#   <Cell 'LoL Data From OP.GG'.E208>,
#   <Cell 'LoL Data From OP.GG'.E209>,
#   <Cell 'LoL Data From OP.GG'.E210>))

# %% [markdown]
# Change Value

# %%
for row in ws.iter_rows(max_row = 1):
    for cell in row:
        if cell.value == 'LoL Data From OP.GG':
            cell.value = 'LoL Data From op.gg'

# %% [markdown]
# Insert&Delete Rows&Cols

# %%
# ws.insert_rows(2)    # 행 삽입
# ws.insert_rows(2, 5)    # 2번째 행에 5개의 행을 삽입
ws.insert_cols(3)
ws.delete_cols(3)

# %% [markdown]
# Move

# %%
# ws.move_range('C2:F'+str(ws.max_row), rows = 10, cols = -1)

# %% [markdown]
# New Sheet

# %%
ws2 = wb.create_sheet()
ws2.title = 'Charts'

ws3 = wb.create_sheet()
ws3.title = 'Formula'

# %% [markdown]
# Bar Chart
#
#     from openpyxl.chart import Barchart

# %%
from openpyxl.chart import BarChart, Reference
refer = Reference(ws, min_row = 3, max_row = ws.max_row,
                      min_col = 3, max_col = 3)    # win rate
bar_chart = BarChart()
bar_chart.add_data(refer)
ws2.add_chart(bar_chart, 'A1')

# %%
refer = Reference(ws, min_row = 2, max_row = ws.max_row,
                      min_col = 3, max_col = 3)    
bar_chart2 = BarChart()
bar_chart2.add_data(refer, titles_from_data = True)
bar_chart2.title = 'Win Rate'
bar_chart2.stype = 20
bar_chart2.y_axis.title = 'win rate'
bar_chart2.x_axis.title = 'Champion'
ws2.add_chart(bar_chart2, 'J1')

# %% [markdown]
# Add Image

# %%
# Make Image
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(data = data[data['position']=='Support'].sort_values(by = 'pick_rate',
                                                                ascending = False)
            ,x = 'name', y = 'pick_rate')
plt.xticks(rotation = 75, size = 8)
plt.savefig('Pick Rate Of Supporters.png')

# %%
img = openpyxl.drawing.image.Image('Pick Rate Of Supporters.png')
ws2.add_image(img, 'A15')

# %% [markdown]
# Function
#
#
# ![image.png](attachment:image.png)

# %%
import datetime

ws3['A1'] = 'Today'
ws3['B1'] = datetime.datetime.today()

ws3['A2'] = 'Sum of 1, 2, 3 is'
ws3['B2'] = "=SUM(1, 2, 3)"

ws3['A3'] = 'Average of 1, 2, 3 is'
ws3['B3'] = "= AVERAGE(1, 2, 3)"

# %% [markdown]
# Save Workbook

# %%
wb.save('LoL data.xlsx')
